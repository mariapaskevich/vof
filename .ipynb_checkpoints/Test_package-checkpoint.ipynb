# %%
import vof
from vof import forecaster
from vof import optimizer

# %%
#pip install altair

# %%
import numpy as np
import matplotlib.pyplot as plt
import altair as alt
import pandas as pd
import statsmodels.api as sm
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
import statsmodels.tsa.stattools
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
import time
import random
#from fbprophet import Prophet
from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.multioutput import MultiOutputRegressor
import lightgbm as lgb
from datetime import date
import nevergrad as ng
from joblib import Parallel, delayed


plt.rcParams['figure.figsize'] = [18, 8]
plt.rcParams.update({'font.size': 22})

# %%
data = pd.read_csv("data/district/predictions_2019.csv", index_col=0, parse_dates=True)#pd.read_csv('sales_FOODS_3_090_TX_2.csv')
data.head(5)
# Out:
#                      Prophet 30d  CB Model 30d  Prophet 60d  LR Model 240d  \
# Time
# 2019-01-02 00:00:00     9.712369      9.516061     9.732844      10.082039
# 2019-01-02 01:00:00     9.537794      9.329764     9.526740       9.905469
# 2019-01-02 02:00:00     9.346844      9.225298     9.357172       9.752310
# 2019-01-02 03:00:00     9.238202      9.140338     9.258282       9.633302
# 2019-01-02 04:00:00     9.222486      9.122567     9.222533       9.600721
#
#                      LR Model 30d  LR Model 60d  LR Model 120d  Prophet 120d  \
# Time
# 2019-01-02 00:00:00     10.034193      9.860739       9.931228      9.475604
# 2019-01-02 01:00:00      9.848606      9.685257       9.755594      9.250441
# 2019-01-02 02:00:00      9.685450      9.537204       9.604944      9.048528
# 2019-01-02 03:00:00      9.547768      9.422706       9.488390      8.965614
# 2019-01-02 04:00:00      9.502948      9.403288       9.459666      8.902531
#
#                      Theta 30d  Theta 60d  Theta 120d  Theta 240d  \
# Time
# 2019-01-02 00:00:00   9.992034   9.986460   10.074619   10.037784
# 2019-01-02 01:00:00   9.799050   9.784246    9.843274    9.809841
# 2019-01-02 02:00:00   9.646126   9.618324    9.656499    9.620984
# 2019-01-02 03:00:00   9.534998   9.506044    9.530117    9.501419
# 2019-01-02 04:00:00   9.499663   9.469673    9.476750    9.455269
#
#                      CB Model 60d  CB Model 240d  CB Model 120d  Prophet 240d  \
# Time
# 2019-01-02 00:00:00      9.478454       9.477245       9.469355      9.521947
# 2019-01-02 01:00:00      9.314212       9.310756       9.320833      9.283847
# 2019-01-02 02:00:00      9.217455       9.230141       9.192942      9.021519
# 2019-01-02 03:00:00      9.155913       9.161070       9.141137      8.909141
# 2019-01-02 04:00:00      9.125739       9.136762       9.136573      8.850692
#
#                          Fact    SNaive
# Time
# 2019-01-02 00:00:00  9.791285  9.587180
# 2019-01-02 01:00:00  9.595427  9.421677
# 2019-01-02 02:00:00  9.538146  9.302606
# 2019-01-02 03:00:00  9.420105  9.151197
# 2019-01-02 04:00:00  9.364424  9.159970

# %% [markdown]
# # Creating forecast from Fact data
#
# We start with creating a forecaster oblect from data['Fact'] with target mentric (the one to predict) also equal to 'Fact'

# %%
tmp = forecaster.RecursiveForecaster(data[['Fact']], 
                          target='Fact')
tmp.y
# Out:
# Time
# 2019-01-02 00:00:00     9.791285
# 2019-01-02 01:00:00     9.595427
# 2019-01-02 02:00:00     9.538146
# 2019-01-02 03:00:00     9.420105
# 2019-01-02 04:00:00     9.364424
#                          ...
# 2019-12-31 19:00:00    12.082850
# 2019-12-31 20:00:00    11.582850
# 2019-12-31 21:00:00    11.257850
# 2019-12-31 22:00:00    10.887850
# 2019-12-31 23:00:00    10.482850
# Name: Fact, Length: 8736, dtype: float64

# %% [markdown]
# ## Estimating Lags and adding them to the object

# %%
def estimateSignificantLags(ts, nlags = 360, significantLags = 11): 
    pacf = sm.tsa.stattools.pacf(ts, nlags)
    lags = np.argsort(-np.abs(pacf))[1:significantLags+1]
    plt.plot(pacf,'*--')
    plt.plot(lags,pacf[lags],'o')
    return lags

# %%
lags = estimateSignificantLags(tmp.y, significantLags = 10)
# add lags for certain days
lags = np.unique(np.hstack([lags]))
print(np.sort(lags))
# Out:
# [  1   2   3   5  23  24  26  50 168 169]

# %%
tmp.add_lag_features(np.sort(lags))

# %%
tmp.x.head(5)
# Out:
#                         lag_1     lag_2     lag_3  lag_5  lag_23  lag_24  \
# Time
# 2019-01-02 00:00:00       NaN       NaN       NaN    NaN     NaN     NaN
# 2019-01-02 01:00:00  9.791285       NaN       NaN    NaN     NaN     NaN
# 2019-01-02 02:00:00  9.595427  9.791285       NaN    NaN     NaN     NaN
# 2019-01-02 03:00:00  9.538146  9.595427  9.791285    NaN     NaN     NaN
# 2019-01-02 04:00:00  9.420105  9.538146  9.595427    NaN     NaN     NaN
#
#                      lag_26  lag_50  lag_168  lag_169
# Time
# 2019-01-02 00:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 01:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 02:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 03:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 04:00:00     NaN     NaN      NaN      NaN

# %% [markdown]
# ## Now the dataset is ready, so we can start building a dataframe with different predictions for further optimization.
# All predictions will be in the same dataframe optimization_df together with the Fact data.
# We run several prediction models

# %%
models = {'Naive':'daily naive',
          'LR': linear_model.LinearRegression()}#,
          #'CB': CatBoostRegressor(verbose=False,learning_rate = 0.01,depth=6,l2_leaf_reg=4),
          #'RF': RandomForestRegressor(),
          #'LGBM': lgb.LGBMRegressor()}

optimization_df = pd.DataFrame()

for model in models.keys():
    
    pred_df = tmp.create_recursive_prediction(models[model],
                      start_day='2019-01-12',
                      last_known_day='2019-03-01',
                      prediction_day='2019-03-02',
                      terminal_day='2019-03-15',
                      freq='H',
                      h=72).melt(ignore_index=False).reset_index().set_index(['variable','index']).dropna()

    pred_df['model'] = str(models[model])
    optimization_df = optimization_df.append(pred_df)
    
optimization_df.reset_index(inplace=True)
optimization_df.columns = ['prediction_date','ts','value','model']
# Out:
# INFO:numexpr.utils:Note: NumExpr detected 64 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:numexpr.utils:NumExpr defaulting to 8 threads.
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# Im in create_naive_prediction!
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()
# LinearRegression()

# %%
optimization_df.model.value_counts()

# %%
fact = optimization_df.loc[optimization_df.model=='LGBMRegressor()'].copy()#.join('tmp.y.loc[optimization_df.index]')
fact.set_index('ts', inplace=True)
fact['model'] = 'Fact'
fact['value'] = tmp.y.loc[fact.index]
fact.reset_index(inplace=True)

if len(optimization_df.loc[optimization_df.model=='Fact'])==0:
    optimization_df = optimization_df.append(fact)

optimization_df.set_index('ts', inplace=True)

# %%
alt.data_transformers.disable_max_rows()

alt.Chart(optimization_df).mark_line().encode(
    x='ts:T',
    y=alt.Y('value:Q',scale=alt.Scale(zero=False)),
    color=alt.Color('prediction_date:N', legend=None),
    row='model:N'
).properties(width=600, height=150).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# # Optimizer to choose from several predictions
#
# Predictions are ready. Now we are creating a child class for Electricity Peak Case.
# We need the child class to pass there task-specific cost functions and other constant values like PEAK_POWER_LIMIT, BATTERY_CHARGE, BATTERY_CAPACITY end so on

# %%
class OptimalDecisionMakersElectricityPeak(optimizer.OptimalDecisionMakers):
    

    def __init__(self, data, target):
        super().__init__(data, target)
        self.EVALUATE = False
        self.TIME_HORIZON = 72#168
        self.DECISION_TIMESTEP = 24
        self.PEAK_POWER_LIMIT = 13
        self.BATTERY_CHARGE = 0
        self.BATTERY_CAPACITY = 1000
        self.BATTERY_EFFICIENCY = .99
        self.INVERTER_CAPACITY = 80
        
    def cost_function(self,solution,battery_charge):
        #print(battery_charge)
        cumsum = np.cumsum(solution) + battery_charge

        #battery capacity penalty:
        violations_battery = (np.sum(np.where(cumsum>self.BATTERY_CAPACITY)) + np.sum(np.where(cumsum<0))) * 10000
        
        
        #penalty for putting electricity back to the grid
        if self.EVALUATE:
            grid_load = (self.data.loc[self.data.model==target,'value']+solution).values
        else:
            #print(self.candidate.shape)
            grid_load = (self.candidate+solution).values
        
        violations_demand = -np.sum(grid_load[np.where(grid_load<0)]) * 10000

        #penlty for high peak in load
        margin = (self.PEAK_POWER_LIMIT - grid_load)
        violations_peak = -np.sum(margin[np.where(margin < 0)]) * 10000

        #penalty for battery losses
        battery_usage = (1 - self.BATTERY_EFFICIENCY) * np.sum(np.abs(solution)) * 1000

        total_cost = violations_battery + violations_demand + violations_peak + battery_usage
        return total_cost
    
        
    def calculate_optimal_decision(self, model):
        
        print(model)

        total_steps = self.data.prediction_date.unique()

        #recommendation = np.array([])
        recommendation = pd.Series()
        battery_ch = self.BATTERY_CHARGE

        for step in total_steps:
            print(step)
            par = ng.p.Array(shape=(self.TIME_HORIZON,)).set_bounds(lower=-self.INVERTER_CAPACITY, upper=self.INVERTER_CAPACITY)
            instru = ng.p.Instrumentation(par,battery_ch)
            optimizer = ng.optimizers.CMA(parametrization=instru, budget=10000)

            try:
                self.candidate = self.data.loc[(self.data.prediction_date==step)&(self.data.model==model),'value']
            except:
                #print(self.optimal_decisions_df.shape)
                print(self.data.loc[(self.data.prediction_date==step)&(self.data.model==model),'value'])


            step_recommendation = optimizer.minimize(self.cost_function)

            #because step_recommendation returns a tuple, we need to access element with index [0][0]:           
            #recommendation = np.append(recommendation,step_recommendation[0][0].value[0:self.DECISION_TIMESTEP])
            
            recommendation = recommendation.append(pd.Series(data=step_recommendation[0][0].value[0:self.DECISION_TIMESTEP],
                                                             index=np.array(self.data.loc[(self.data.prediction_date==step)&(self.data.model==model),'value'].iloc[0:self.DECISION_TIMESTEP].index)))
            battery_ch += sum(step_recommendation[0][0].value[0:self.DECISION_TIMESTEP])
        
        return pd.Series(name=model, data=recommendation)
    

    def select_value_optimal_model(self,models,return_predictions=False):
        
        random.seed(42)
        
        #self.optimal_decisions_df = pd.DataFrame(index=(self.x.index),columns=self.x.columns).iloc[:-self.TIME_HORIZON]
        
        #parallel_optimal_decision_result = (Parallel(n_jobs=-1, verbose = 1000)(delayed(self.calculate_optimal_decision)(col) for col in range(len(self.optimal_decisions_df.columns))))
        
        self.optimal_decision_result = (Parallel(n_jobs=-1, verbose = 1000)(delayed(self.calculate_optimal_decision)(model) for model in models))

                
        #for i in parallel_optimal_decision_result:
        #    self.optimal_decisions_df.iloc[:,i.name] = i.values

        return self.optimal_decision_result#self.optimal_decisions_df
    
    def evaluate(self):
        
        evaluation_df = pd.DataFrame(index=range(len(self.optimal_decision_result)), columns=['model','cost_evaluation','error_evaluation'])
        for i in range(len(self.optimal_decision_result)):  
            evaluation_df.loc[i,'model'] = self.optimal_decision_result[i].name
            evaluation_df.loc[i,'cost_evaluation'] = (self.optimal_decision_result[i]+self.data.loc[self.data.model=='Fact','value'])[(self.optimal_decision_result[i]+self.data.loc[self.data.model=='Fact','value'])>self.PEAK_POWER_LIMIT].sum()
            evaluation_df.loc[i,'error_evaluation'] = np.mean(np.abs(self.data.loc[self.data.model=='Fact','value'] - self.data.loc[self.data.model==self.optimal_decision_result[i].name,'value']))
            #print(evaluation_df)
            
        return evaluation_df#cost_evaluation, error_evaluation
        
    def select_value_optimal_hyperparameters():
        return

# %% [markdown]
# ## Now just creating an oblect of this child class using optimization_df from the previous steps

# %%
odm = OptimalDecisionMakersElectricityPeak(optimization_df,'Fact')

# %% [markdown]
# ## Running optimization to select the optimal model

# %%
sol = odm.select_value_optimal_model(models=optimization_df.model.unique())
sol
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 64 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:  5.4min
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:  5.4min remaining:  8.1min
# [Parallel(n_jobs=-1)]: Done   3 out of   5 | elapsed:  5.4min remaining:  3.6min
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.5min remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:  5.5min finished
# [2019-03-02 00:00:00    0.128009
#  2019-03-02 01:00:00    0.233333
#  2019-03-02 02:00:00    0.059577
#  2019-03-02 03:00:00    0.122904
#  2019-03-02 04:00:00    0.151302
#                           ...
#  2019-04-01 19:00:00    0.015451
#  2019-04-01 20:00:00    0.366233
#  2019-04-01 21:00:00    0.294915
#  2019-04-01 22:00:00   -0.018933
#  2019-04-01 23:00:00    0.246351
#  Name: LinearRegression(), Length: 744, dtype: float64,
#  2019-03-02 00:00:00    0.009241
#  2019-03-02 01:00:00    0.010676
#  2019-03-02 02:00:00    0.023753
#  2019-03-02 03:00:00   -0.013375
#  2019-03-02 04:00:00    0.000924
#                           ...
#  2019-04-01 19:00:00   -0.137040
#  2019-04-01 20:00:00   -0.103982
#  2019-04-01 21:00:00    0.017482
#  2019-04-01 22:00:00    0.015486
#  2019-04-01 23:00:00    0.101620
#  Name: <catboost.core.CatBoostRegressor object at 0x7f17301fe810>, Length: 744, dtype: float64,
#  2019-03-02 00:00:00    0.001556
#  2019-03-02 01:00:00    0.000049
#  2019-03-02 02:00:00    0.000107
#  2019-03-02 03:00:00    0.222229
#  2019-03-02 04:00:00    0.000138
#                           ...
#  2019-04-01 19:00:00   -0.204660
#  2019-04-01 20:00:00    0.003936
#  2019-04-01 21:00:00    0.022748
#  2019-04-01 22:00:00   -0.013294
#  2019-04-01 23:00:00    0.214722
#  Name: RandomForestRegressor(), Length: 744, dtype: float64,
#  2019-03-02 00:00:00   -0.008262
#  2019-03-02 01:00:00    0.059324
#  2019-03-02 02:00:00    0.000998
#  2019-03-02 03:00:00    1.010817
#  2019-03-02 04:00:00   -0.010015
#                           ...
#  2019-04-01 19:00:00   -0.059058
#  2019-04-01 20:00:00   -0.025451
#  2019-04-01 21:00:00   -0.002636
#  2019-04-01 22:00:00    0.008626
#  2019-04-01 23:00:00    0.014093
#  Name: LGBMRegressor(), Length: 744, dtype: float64,
#  2019-03-02 00:00:00    0.205984
#  2019-03-02 01:00:00    0.013088
#  2019-03-02 02:00:00    1.108933
#  2019-03-02 03:00:00   -0.003862
#  2019-03-02 04:00:00    0.187517
#                           ...
#  2019-04-01 19:00:00    0.044736
#  2019-04-01 20:00:00    0.208935
#  2019-04-01 21:00:00   -0.048639
#  2019-04-01 22:00:00    0.038167
#  2019-04-01 23:00:00    0.030802
#  Name: Fact, Length: 744, dtype: float64]

# %%
for col in range(len(sol)):
    plt.plot(sol[col].dropna()+tmp.y.loc['2019-03-02':'2019-06-01'], label=sol[col].name)

#plt.plot(tmp.y.loc['2019-03-02':'2019-04-01'], label='Fact', lw=3)
plt.legend()

# %% [markdown]
# ## Evaluation returns outputs of cost function for each of the models:

# %%
EVALUATE = True
results = odm.evaluate()
#plt.scatter(results[0],results[1])

plt.scatter(results['error_evaluation'],results['cost_evaluation'])

results
# Out:
#                                                model cost_evaluation  \
# 0                                 LinearRegression()     5379.883519
# 1  <catboost.core.CatBoostRegressor object at 0x7...     5687.639016
# 2                            RandomForestRegressor()     6980.201629
# 3                                    LGBMRegressor()     6493.347825
# 4                                               Fact     2697.321456
#
#   error_evaluation
# 0         0.433795
# 1         0.625629
# 2         0.651607
# 3         0.641718
# 4              0.0

# %%
tmp.y
# Out:
# Time
# 2019-01-02 00:00:00     9.791285
# 2019-01-02 01:00:00     9.595427
# 2019-01-02 02:00:00     9.538146
# 2019-01-02 03:00:00     9.420105
# 2019-01-02 04:00:00     9.364424
#                          ...
# 2019-12-31 19:00:00    12.082850
# 2019-12-31 20:00:00    11.582850
# 2019-12-31 21:00:00    11.257850
# 2019-12-31 22:00:00    10.887850
# 2019-12-31 23:00:00    10.482850
# Name: Fact, Length: 8736, dtype: float64

# %%
import datetime

def create_naive_prediction(tmp, model_name,
                  start_day='2019-01-02', 
                  last_known_day='2019-12-01', 
                  prediction_day='2019-12-02',
                  frequency='D',
                  horizon=10):     

    print(model_name)

    if frequency=='D':
        pred_values = horizon*list(tmp.y.loc[last_known_day].values)
    
    elif frequency=='h':
        pred_values = int(horizon/24)*list(tmp.y.loc[last_known_day].values)
    else:
        return 
        
    print(len(pred_values))
    pred_index = pd.date_range(start=prediction_day, 
                               periods=horizon, 
                               freq=frequency)

    pred_df = pd.DataFrame(index=pred_index, 
                           columns=[tmp.y.name],
                           data=pred_values)
    return pred_df


create_naive_prediction(tmp, 'daily naive',
                  start_day='2019-01-02', 
                  last_known_day='2019-12-01', 
                  prediction_day='2019-12-02',
                  frequency='h',
                  horizon=48)
# Out:
# daily naive
# 48
#                          Fact
# 2019-12-02 00:00:00  10.20285
# 2019-12-02 01:00:00   9.99285
# 2019-12-02 02:00:00   9.86785
# 2019-12-02 03:00:00   9.72785
# 2019-12-02 04:00:00   9.64785
# 2019-12-02 05:00:00   9.68785
# 2019-12-02 06:00:00   9.69785
# 2019-12-02 07:00:00   9.64285
# 2019-12-02 08:00:00   9.85785
# 2019-12-02 09:00:00  10.13285
# 2019-12-02 10:00:00  10.42285
# 2019-12-02 11:00:00  10.60785
# 2019-12-02 12:00:00  10.62785
# 2019-12-02 13:00:00  10.64785
# 2019-12-02 14:00:00  10.68785
# 2019-12-02 15:00:00  10.68785
# 2019-12-02 16:00:00  10.62785
# 2019-12-02 17:00:00  10.66785
# 2019-12-02 18:00:00  10.88285
# 2019-12-02 19:00:00  10.81285
# 2019-12-02 20:00:00  10.72785
# 2019-12-02 21:00:00  10.65785
# 2019-12-02 22:00:00  10.47285
# 2019-12-02 23:00:00  10.24285
# 2019-12-03 00:00:00  10.20285
# 2019-12-03 01:00:00   9.99285
# 2019-12-03 02:00:00   9.86785
# 2019-12-03 03:00:00   9.72785
# 2019-12-03 04:00:00   9.64785
# 2019-12-03 05:00:00   9.68785
# 2019-12-03 06:00:00   9.69785
# 2019-12-03 07:00:00   9.64285
# 2019-12-03 08:00:00   9.85785
# 2019-12-03 09:00:00  10.13285
# 2019-12-03 10:00:00  10.42285
# 2019-12-03 11:00:00  10.60785
# 2019-12-03 12:00:00  10.62785
# 2019-12-03 13:00:00  10.64785
# 2019-12-03 14:00:00  10.68785
# 2019-12-03 15:00:00  10.68785
# 2019-12-03 16:00:00  10.62785
# 2019-12-03 17:00:00  10.66785
# 2019-12-03 18:00:00  10.88285
# 2019-12-03 19:00:00  10.81285
# 2019-12-03 20:00:00  10.72785
# 2019-12-03 21:00:00  10.65785
# 2019-12-03 22:00:00  10.47285
# 2019-12-03 23:00:00  10.24285

# %%
list(tmp.y.loc[last_known_day].values)*3
# Out:
# [10.85867122,
#  10.62897262,
#  10.4764881,
#  10.36074206,
#  10.34967976,
#  10.49202636,
#  10.79416008,
#  11.31878736,
#  12.41077788,
#  13.30088604,
#  13.78317402,
#  13.9957171,
#  14.0461597,
#  13.93662172,
#  14.07983134,
#  14.08474828,
#  13.96853746,
#  13.705336,
#  13.32718962,
#  12.87759738,
#  12.388298740000002,
#  11.97761784,
#  11.57171676,
#  11.209582139999998,
#  10.85867122,
#  10.62897262,
#  10.4764881,
#  10.36074206,
#  10.34967976,
#  10.49202636,
#  10.79416008,
#  11.31878736,
#  12.41077788,
#  13.30088604,
#  13.78317402,
#  13.9957171,
#  14.0461597,
#  13.93662172,
#  14.07983134,
#  14.08474828,
#  13.96853746,
#  13.705336,
#  13.32718962,
#  12.87759738,
#  12.388298740000002,
#  11.97761784,
#  11.57171676,
#  11.209582139999998,
#  10.85867122,
#  10.62897262,
#  10.4764881,
#  10.36074206,
#  10.34967976,
#  10.49202636,
#  10.79416008,
#  11.31878736,
#  12.41077788,
#  13.30088604,
#  13.78317402,
#  13.9957171,
#  14.0461597,
#  13.93662172,
#  14.07983134,
#  14.08474828,
#  13.96853746,
#  13.705336,
#  13.32718962,
#  12.87759738,
#  12.388298740000002,
#  11.97761784,
#  11.57171676,
#  11.209582139999998]

# %%
tmp.y.loc[last_known_day]
# Out:
# Time
# 2019-03-01 00:00:00    10.858671
# 2019-03-01 01:00:00    10.628973
# 2019-03-01 02:00:00    10.476488
# 2019-03-01 03:00:00    10.360742
# 2019-03-01 04:00:00    10.349680
# 2019-03-01 05:00:00    10.492026
# 2019-03-01 06:00:00    10.794160
# 2019-03-01 07:00:00    11.318787
# 2019-03-01 08:00:00    12.410778
# 2019-03-01 09:00:00    13.300886
# 2019-03-01 10:00:00    13.783174
# 2019-03-01 11:00:00    13.995717
# 2019-03-01 12:00:00    14.046160
# 2019-03-01 13:00:00    13.936622
# 2019-03-01 14:00:00    14.079831
# 2019-03-01 15:00:00    14.084748
# 2019-03-01 16:00:00    13.968537
# 2019-03-01 17:00:00    13.705336
# 2019-03-01 18:00:00    13.327190
# 2019-03-01 19:00:00    12.877597
# 2019-03-01 20:00:00    12.388299
# 2019-03-01 21:00:00    11.977618
# 2019-03-01 22:00:00    11.571717
# 2019-03-01 23:00:00    11.209582
# Name: Fact, dtype: float64
