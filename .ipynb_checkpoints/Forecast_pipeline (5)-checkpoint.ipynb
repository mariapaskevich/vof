# %%
# !pip install -r requirements.txt
# !pip install fbprophet
# !pip install xlrd
# !pip install openpyxl
# Out:
# Collecting openpyxl
#   Downloading openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
#      |████████████████████████████████| 243 kB 8.0 MB/s eta 0:00:01
# Collecting et-xmlfile
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.0.7

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
import seaborn as sns
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
import statsmodels.tsa.stattools
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
import time
from darts import TimeSeries
from darts.models import (
    FFT,
    ExponentialSmoothing,
    Theta
)
from darts.metrics import mape
from darts.utils.missing_values import fill_missing_values
from fbprophet import Prophet
from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.multioutput import MultiOutputRegressor

plt.rcParams['figure.figsize'] = [18, 8]
plt.rcParams.update({'font.size': 22})

# %%
import warnings
warnings.filterwarnings("ignore")
import logging
logging.disable(logging.CRITICAL)

# %%
data = pd.read_csv('data/district/Actuals.csv')
data = data.loc[data.Time<'2020-11-06'] #getting rid of the overlap
data.Time = data.Time.astype('datetime64[ns]')
data.set_index('Time', inplace=True)

data

# data_Interim = pd.read_csv('Interim_dataset/Actuals_Interim.csv')
# data_Interim['Time'] = data_Interim['Time'].astype('datetime64[ns]')
# data_Interim.set_index('Time', inplace=True)

# data_Forecast_Interim = pd.read_csv('Interim_dataset/Forecasts_Interim.csv')[['Temperature (C) ','Pressure_kpa',
#                        'Cloud Cover (%)','Wind Direction (deg)',
#                       'Wind Speed (kmh)','Time']].dropna()

# data_Forecast_Interim['Time'] = data_Forecast_Interim['Time'].astype('datetime64[ns]')
# data_Forecast_Interim.set_index('Time', inplace=True)

# data_Forecast_Interim['Load (kW)'] = data_Interim['Load (kW)']
# data_Forecast_Interim.reset_index(inplace=True)
# Out:
#                         Load (kW)  Pressure_kpa  Cloud Cover (%)  \
# Time
# 2017-03-18 00:00:00  1.031472e+06    1012.48000            2.125
# 2017-03-18 01:00:00  1.007206e+06    1011.61875            0.000
# 2017-03-18 02:00:00  9.861084e+05    1010.72000            2.125
# 2017-03-18 03:00:00  9.707610e+05    1011.37625           17.125
# 2017-03-18 04:00:00  9.622584e+05    1011.50000           18.625
# ...                           ...           ...              ...
# 2020-11-05 19:00:00  1.141299e+06    1010.35000           53.375
# 2020-11-05 20:00:00  1.112590e+06    1011.10000           36.875
# 2020-11-05 21:00:00  1.086038e+06    1011.56250           33.875
# 2020-11-05 22:00:00  1.062103e+06    1011.45000           58.625
# 2020-11-05 23:00:00  1.022584e+06    1011.38750           53.625
#
#                      Humidity (%)  Temperature (C)   Wind Direction (deg)  \
# Time
# 2017-03-18 00:00:00     79.333333         16.764386               285.250
# 2017-03-18 01:00:00     82.166667         15.729386               285.000
# 2017-03-18 02:00:00     81.666667         15.816886               316.000
# 2017-03-18 03:00:00     82.250000         15.919386               327.000
# 2017-03-18 04:00:00     82.333333         15.769386               282.250
# ...                           ...               ...                   ...
# 2020-11-05 19:00:00     69.333333         18.319386               342.000
# 2020-11-05 20:00:00     69.333333         17.819386               221.500
# 2020-11-05 21:00:00     69.333333         17.641886                 5.125
# 2020-11-05 22:00:00     70.500000         16.499386               180.750
# 2020-11-05 23:00:00     71.833333         15.096886                15.875
#
#                      Wind Speed (kmh)
# Time
# 2017-03-18 00:00:00           6.25375
# 2017-03-18 01:00:00           9.20500
# 2017-03-18 02:00:00          11.28375
# 2017-03-18 03:00:00           7.16875
# 2017-03-18 04:00:00           0.78000
# ...                               ...
# 2020-11-05 19:00:00          10.18625
# 2020-11-05 20:00:00           8.77000
# 2020-11-05 21:00:00           9.94125
# 2020-11-05 22:00:00          10.16250
# 2020-11-05 23:00:00          10.09375
#
# [31896 rows x 7 columns]

# %%
# cloudcover_percent = pd.read_excel('data/district/WeatherForecasts/Cloudcover_percent.xlsx', index_col='Time',dtype={'Time':'datetime64[ns]'}, engine='openpyxl')
# pressure_kpa = pd.read_excel('data/district/WeatherForecasts/Pressure_kpa.xlsx', index_col='Time',dtype={'Time':'datetime64[ns]'})
# temperature_Celcius = pd.read_excel('data/district/WeatherForecasts/Temperature_Celcius.xlsx', index_col='Time',dtype={'Time':'datetime64[ns]'})
# winddirection_degree = pd.read_excel('data/district/WeatherForecasts/Winddirection_degree.xlsx', index_col='Time',dtype={'Time':'datetime64[ns]'})
# windspeed_kmh = pd.read_excel('data/district/WeatherForecasts/Windspeed_kmh.xlsx', index_col='Time',dtype={'Time':'datetime64[ns]'})

# cloudcover_percent.index = cloudcover_percent.index.astype('datetime64[ns]').round('1s')
# pressure_kpa.index = pressure_kpa.index.astype('datetime64[ns]').round('1s')
# temperature_Celcius.index = temperature_Celcius.index.astype('datetime64[ns]').round('1s')
# winddirection_degree.index = winddirection_degree.index.astype('datetime64[ns]').round('1s')
# windspeed_kmh.index = windspeed_kmh.index.astype('datetime64[ns]').round('1s')

# data['Cloud Cover (%)'] = cloudcover_percent['Cloud Cover (%)']#.astype('datetime64[ns]')
# data['Pressure_kpa'] = pressure_kpa['Pressure (kpa)']#.astype('datetime64[ns]')
# data['Temperature (C) '] = temperature_Celcius['Temperature (C)']#.astype('datetime64[ns]')
# data['Wind Direction (deg)'] = winddirection_degree['Wind Direction (deg)']#.astype('datetime64[ns]')
# data['Wind Speed (kmh)'] = windspeed_kmh['Wind Speed (kmh)']#.astype('datetime64[ns]')

data.reset_index(inplace=True)

# data = data.append(data_Forecast_Interim).drop(['Humidity (%)'],axis=1)

data['day_of_week'] = pd.to_datetime(data.Time).dt.weekday.values
data['time_of_day'] = (np.array(range(len(data)))%24)
data['is_weekend'] = data.day_of_week.isin([5,6])
# data['post_covid'] = data.Time>'2020-03-01'

# %%
#data['rolling_1d'] = data['Load (kW)'].shift(24).rolling(24,center=False).mean()
data['rolling_2d'] = data['Load (kW)'].shift(48).rolling(48,center=False).mean()
data['rolling_3d'] = data['Load (kW)'].shift(72).rolling(72,center=False).mean()
data['rolling_5d'] = data['Load (kW)'].shift(120).rolling(120,center=False).mean()
data['rolling_7d'] = data['Load (kW)'].shift(168).rolling(168,center=False).mean()

# %%
data.set_index('Time', inplace=True)

# %%
data['Load (kW)'].iloc[-480:].plot()
data
# Out:
#                         Load (kW)  Pressure_kpa  Cloud Cover (%)  \
# Time
# 2017-03-18 00:00:00  1.031472e+06    1012.48000            2.125
# 2017-03-18 01:00:00  1.007206e+06    1011.61875            0.000
# 2017-03-18 02:00:00  9.861084e+05    1010.72000            2.125
# 2017-03-18 03:00:00  9.707610e+05    1011.37625           17.125
# 2017-03-18 04:00:00  9.622584e+05    1011.50000           18.625
# ...                           ...           ...              ...
# 2020-11-05 19:00:00  1.141299e+06    1010.35000           53.375
# 2020-11-05 20:00:00  1.112590e+06    1011.10000           36.875
# 2020-11-05 21:00:00  1.086038e+06    1011.56250           33.875
# 2020-11-05 22:00:00  1.062103e+06    1011.45000           58.625
# 2020-11-05 23:00:00  1.022584e+06    1011.38750           53.625
#
#                      Humidity (%)  Temperature (C)   Wind Direction (deg)  \
# Time
# 2017-03-18 00:00:00     79.333333         16.764386               285.250
# 2017-03-18 01:00:00     82.166667         15.729386               285.000
# 2017-03-18 02:00:00     81.666667         15.816886               316.000
# 2017-03-18 03:00:00     82.250000         15.919386               327.000
# 2017-03-18 04:00:00     82.333333         15.769386               282.250
# ...                           ...               ...                   ...
# 2020-11-05 19:00:00     69.333333         18.319386               342.000
# 2020-11-05 20:00:00     69.333333         17.819386               221.500
# 2020-11-05 21:00:00     69.333333         17.641886                 5.125
# 2020-11-05 22:00:00     70.500000         16.499386               180.750
# 2020-11-05 23:00:00     71.833333         15.096886                15.875
#
#                      Wind Speed (kmh)  day_of_week  time_of_day  is_weekend  \
# Time
# 2017-03-18 00:00:00           6.25375            5            0        True
# 2017-03-18 01:00:00           9.20500            5            1        True
# 2017-03-18 02:00:00          11.28375            5            2        True
# 2017-03-18 03:00:00           7.16875            5            3        True
# 2017-03-18 04:00:00           0.78000            5            4        True
# ...                               ...          ...          ...         ...
# 2020-11-05 19:00:00          10.18625            3           19       False
# 2020-11-05 20:00:00           8.77000            3           20       False
# 2020-11-05 21:00:00           9.94125            3           21       False
# 2020-11-05 22:00:00          10.16250            3           22       False
# 2020-11-05 23:00:00          10.09375            3           23       False
#
#                        rolling_2d    rolling_3d    rolling_5d    rolling_7d
# Time
# 2017-03-18 00:00:00           NaN           NaN           NaN           NaN
# 2017-03-18 01:00:00           NaN           NaN           NaN           NaN
# 2017-03-18 02:00:00           NaN           NaN           NaN           NaN
# 2017-03-18 03:00:00           NaN           NaN           NaN           NaN
# 2017-03-18 04:00:00           NaN           NaN           NaN           NaN
# ...                           ...           ...           ...           ...
# 2020-11-05 19:00:00  1.062313e+06  1.015167e+06  1.073313e+06  1.086139e+06
# 2020-11-05 20:00:00  1.063869e+06  1.014760e+06  1.072780e+06  1.085935e+06
# 2020-11-05 21:00:00  1.065147e+06  1.014530e+06  1.072240e+06  1.085802e+06
# 2020-11-05 22:00:00  1.066351e+06  1.014434e+06  1.071809e+06  1.085664e+06
# 2020-11-05 23:00:00  1.067463e+06  1.014428e+06  1.071444e+06  1.085468e+06
#
# [31896 rows x 14 columns]

# %%
data.loc['2020-10-16 07:00:00']
# Out:
# Load (kW)               1008339.808000
# Pressure_kpa               1012.350000
# Cloud Cover (%)              13.625000
# Humidity (%)                 87.000000
# Temperature (C)              11.756886
# Wind Direction (deg)         55.875000
# Wind Speed (kmh)              3.163750
# day_of_week                          4
# time_of_day                          7
# is_weekend                       False
# rolling_2d              1103539.710067
# rolling_3d              1048447.551564
# rolling_5d              1103631.411560
# rolling_7d              1091667.840922
# Name: 2020-10-16 07:00:00, dtype: object

# %% [markdown]
# # Create ES model

# %%
# !pip install 'statsmodels==0.12.0' --force-reinstall # --upgrade

# %%
model = ExponentialSmoothing(data['Load (kW)'].values[0:480], seasonal_periods=168, 
                             trend='add', seasonal='mul', damped_trend=True, use_boxcox=True, initialization_method="estimated").fit()
forecast_seasonal_Holt = model.forecast(24)
plt.plot(forecast_seasonal_Holt)

# %% [markdown]
# # Define config

# %%
startDay = 28
totalDays = 1300
samplingFreq = 24
minimumTrainDuration = samplingFreq * 13
nlags = 360
significantLags = 30
timeHorizon = 24
slidingWindow = True
slidingWindowDays = 28

# %% [markdown]
# # Calculate PACF features

# %%
def estimateSignificantLags(ts, nlags = 360, significantLags = 11): 
    pacf = sm.tsa.stattools.pacf(ts, nlags)
    lags = np.argsort(-np.abs(pacf))[1:significantLags+1]
    plt.plot(pacf,'*--')
    plt.plot(lags,pacf[lags],'o')
    return lags

# %%
lags = estimateSignificantLags(data['Load (kW)'].dropna(), significantLags = significantLags)
# add lags for certain days
lags = np.unique(np.hstack([lags,[47,48,49,70,72,94,96,118,120,144]]))
print(np.sort(lags))
# Out:
# [  1   2   3   5   8  12  13  18  19  20  22  23  24  25  26  47  48  49
#   50  70  72  74  94  96  98 118 120 122 143 144 146 156 157 158 167 168
#  169 170 336 337]

# %% [markdown]
# # Build a forecaster with lagged features

# %%
def add_lag_features(df,lags):
    tmp = df.copy()
    for i in lags:
        tmp['lag_'+str(i)] = tmp['Load (kW)'].shift(i)    
    return tmp

# %%
lags_df = add_lag_features(data,lags)

# %% [markdown]
# ## Recursive forecaster

# %%
def create_prediction(model_name, start_day='2017-04-07', last_known_day='2018-11-07', 
                      prediction_day='2018-11-08', last_prediction_day='2018-11-09',
                      horizon=48):    
    
    X_train = lags_df.drop(['Load (kW)'], axis=1).loc[start_day:last_known_day]
    y_train = lags_df['Load (kW)'].loc[start_day:last_known_day]
    #print(X_train,y_train)
    model_name.fit(X_train,y_train)

    pred_index = pd.date_range(start=prediction_day, periods=horizon, freq='H')
    pred_df = pd.DataFrame(index=pred_index, columns=['Load (kW)'])
    #print('pred_index',pred_index)
    
    dataCopy = data.copy()
    
    for step in pred_index:
        
        dataCopy = add_lag_features(dataCopy,lags)
        #print(dataCopy.loc[step].name)
        X_pred = pd.DataFrame(dataCopy.drop(['Load (kW)'], axis=1).loc[step]).T
        x_index = dataCopy.loc[step].name
        #print(X_pred)
        pred_df.loc[x_index] = model_name.predict(X_pred)
        
        dataCopy.loc[step, 'Load (kW)'] = pred_df.loc[x_index][0]

    return pred_df

# %% [markdown]
# ### Creating a df for all models' outputs:

# %%
overall_pred = pd.DataFrame(index=data.index, columns=['CB Model'])
overall_pred
# Out:
#                     CB Model
# Time
# 2017-03-18 00:00:00      NaN
# 2017-03-18 01:00:00      NaN
# 2017-03-18 02:00:00      NaN
# 2017-03-18 03:00:00      NaN
# 2017-03-18 04:00:00      NaN
# ...                      ...
# 2020-11-05 19:00:00      NaN
# 2020-11-05 20:00:00      NaN
# 2020-11-05 21:00:00      NaN
# 2020-11-05 22:00:00      NaN
# 2020-11-05 23:00:00      NaN
#
# [31896 rows x 1 columns]

# %%
n_days = 365

# %% [markdown]
# # Create prediction for N days: Catboost

# %%
model = CatBoostRegressor(verbose=False,
                          learning_rate = 0.01, 
                          depth=6,
                          l2_leaf_reg=4,
                          cat_features=['day_of_week','time_of_day','is_weekend']
                     )

overall_mape = np.zeros(n_days)
start_day = pd.to_datetime('2017-12-01 07:00:00')

for i in range(n_days):

    last_known_day = (start_day + pd.DateOffset(days=30+i))#.date()
    prediction_day = (last_known_day + pd.DateOffset(days=1))#.date()
    last_prediction_day = str((prediction_day + pd.DateOffset(days=1)))#.date())
    print('prediction_day',prediction_day)

    pred = create_prediction(model, start_day=start_day, last_known_day=last_known_day, 
                             prediction_day=prediction_day, last_prediction_day=prediction_day, 
                             horizon = 41)
    
    prediction = pred.dropna()['Load (kW)'].values[17:41]
    fact = data.loc[pred.dropna().index,'Load (kW)'].values[17:41]

    overall_mape[i] = 100 * np.mean(np.abs(prediction - fact)) / np.mean(np.abs(fact))
    
    overall_pred.loc[pred.index[17:41], 'CB Model'] = pred['Load (kW)'].iloc[17:41]
    
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['CB Model'].values, label='pred')
plt.legend()
plt.show()
print('mape',overall_mape.mean())
# Out:
# prediction_day 2018-01-01 07:00:00
# prediction_day 2018-01-02 07:00:00
# prediction_day 2018-01-03 07:00:00
# prediction_day 2018-01-04 07:00:00
# prediction_day 2018-01-05 07:00:00
# prediction_day 2018-01-06 07:00:00
# prediction_day 2018-01-07 07:00:00
# prediction_day 2018-01-08 07:00:00
# prediction_day 2018-01-09 07:00:00
# prediction_day 2018-01-10 07:00:00
# prediction_day 2018-01-11 07:00:00
# prediction_day 2018-01-12 07:00:00
# prediction_day 2018-01-13 07:00:00
# prediction_day 2018-01-14 07:00:00
# prediction_day 2018-01-15 07:00:00
# prediction_day 2018-01-16 07:00:00
# prediction_day 2018-01-17 07:00:00
# prediction_day 2018-01-18 07:00:00
# prediction_day 2018-01-19 07:00:00
# prediction_day 2018-01-20 07:00:00
# prediction_day 2018-01-21 07:00:00
# prediction_day 2018-01-22 07:00:00
# prediction_day 2018-01-23 07:00:00
# prediction_day 2018-01-24 07:00:00
# prediction_day 2018-01-25 07:00:00
# prediction_day 2018-01-26 07:00:00
# prediction_day 2018-01-27 07:00:00
# prediction_day 2018-01-28 07:00:00
# prediction_day 2018-01-29 07:00:00
# prediction_day 2018-01-30 07:00:00
# prediction_day 2018-01-31 07:00:00
# prediction_day 2018-02-01 07:00:00
# prediction_day 2018-02-02 07:00:00
# prediction_day 2018-02-03 07:00:00
# prediction_day 2018-02-04 07:00:00
# prediction_day 2018-02-05 07:00:00
# prediction_day 2018-02-06 07:00:00
# prediction_day 2018-02-07 07:00:00
# prediction_day 2018-02-08 07:00:00
# prediction_day 2018-02-09 07:00:00
# prediction_day 2018-02-10 07:00:00
# prediction_day 2018-02-11 07:00:00
# prediction_day 2018-02-12 07:00:00
# prediction_day 2018-02-13 07:00:00
# prediction_day 2018-02-14 07:00:00
# prediction_day 2018-02-15 07:00:00
# prediction_day 2018-02-16 07:00:00
# prediction_day 2018-02-17 07:00:00
# prediction_day 2018-02-18 07:00:00
# prediction_day 2018-02-19 07:00:00
# prediction_day 2018-02-20 07:00:00
# prediction_day 2018-02-21 07:00:00
# prediction_day 2018-02-22 07:00:00
# prediction_day 2018-02-23 07:00:00
# prediction_day 2018-02-24 07:00:00
# prediction_day 2018-02-25 07:00:00
# prediction_day 2018-02-26 07:00:00
# prediction_day 2018-02-27 07:00:00
# prediction_day 2018-02-28 07:00:00
# prediction_day 2018-03-01 07:00:00
# prediction_day 2018-03-02 07:00:00
# prediction_day 2018-03-03 07:00:00
# prediction_day 2018-03-04 07:00:00
# prediction_day 2018-03-05 07:00:00
# prediction_day 2018-03-06 07:00:00
# prediction_day 2018-03-07 07:00:00
# prediction_day 2018-03-08 07:00:00
# prediction_day 2018-03-09 07:00:00
# prediction_day 2018-03-10 07:00:00
# prediction_day 2018-03-11 07:00:00
# prediction_day 2018-03-12 07:00:00
# prediction_day 2018-03-13 07:00:00
# prediction_day 2018-03-14 07:00:00
# prediction_day 2018-03-15 07:00:00
# prediction_day 2018-03-16 07:00:00
# prediction_day 2018-03-17 07:00:00
# prediction_day 2018-03-18 07:00:00
# prediction_day 2018-03-19 07:00:00
# prediction_day 2018-03-20 07:00:00
# prediction_day 2018-03-21 07:00:00
# prediction_day 2018-03-22 07:00:00
# prediction_day 2018-03-23 07:00:00
# prediction_day 2018-03-24 07:00:00
# prediction_day 2018-03-25 07:00:00
# prediction_day 2018-03-26 07:00:00
# prediction_day 2018-03-27 07:00:00
# prediction_day 2018-03-28 07:00:00
# prediction_day 2018-03-29 07:00:00
# prediction_day 2018-03-30 07:00:00
# prediction_day 2018-03-31 07:00:00
# prediction_day 2018-04-01 07:00:00
# prediction_day 2018-04-02 07:00:00
# prediction_day 2018-04-03 07:00:00
# prediction_day 2018-04-04 07:00:00
# prediction_day 2018-04-05 07:00:00
# prediction_day 2018-04-06 07:00:00
# prediction_day 2018-04-07 07:00:00
# prediction_day 2018-04-08 07:00:00
# prediction_day 2018-04-09 07:00:00
# prediction_day 2018-04-10 07:00:00
# prediction_day 2018-04-11 07:00:00
# prediction_day 2018-04-12 07:00:00
# prediction_day 2018-04-13 07:00:00
# prediction_day 2018-04-14 07:00:00
# prediction_day 2018-04-15 07:00:00
# prediction_day 2018-04-16 07:00:00
# prediction_day 2018-04-17 07:00:00
# prediction_day 2018-04-18 07:00:00
# prediction_day 2018-04-19 07:00:00
# prediction_day 2018-04-20 07:00:00
# prediction_day 2018-04-21 07:00:00
# prediction_day 2018-04-22 07:00:00
# prediction_day 2018-04-23 07:00:00
# prediction_day 2018-04-24 07:00:00
# prediction_day 2018-04-25 07:00:00
# prediction_day 2018-04-26 07:00:00
# prediction_day 2018-04-27 07:00:00
# prediction_day 2018-04-28 07:00:00
# prediction_day 2018-04-29 07:00:00
# prediction_day 2018-04-30 07:00:00
# prediction_day 2018-05-01 07:00:00
# prediction_day 2018-05-02 07:00:00
# prediction_day 2018-05-03 07:00:00
# prediction_day 2018-05-04 07:00:00
# prediction_day 2018-05-05 07:00:00
# prediction_day 2018-05-06 07:00:00
# prediction_day 2018-05-07 07:00:00
# prediction_day 2018-05-08 07:00:00
# prediction_day 2018-05-09 07:00:00
# prediction_day 2018-05-10 07:00:00
# prediction_day 2018-05-11 07:00:00
# prediction_day 2018-05-12 07:00:00
# prediction_day 2018-05-13 07:00:00
# prediction_day 2018-05-14 07:00:00
# prediction_day 2018-05-15 07:00:00
# prediction_day 2018-05-16 07:00:00
# prediction_day 2018-05-17 07:00:00
# prediction_day 2018-05-18 07:00:00
# prediction_day 2018-05-19 07:00:00
# prediction_day 2018-05-20 07:00:00
# prediction_day 2018-05-21 07:00:00
# prediction_day 2018-05-22 07:00:00
# prediction_day 2018-05-23 07:00:00
# prediction_day 2018-05-24 07:00:00
# prediction_day 2018-05-25 07:00:00
# prediction_day 2018-05-26 07:00:00
# prediction_day 2018-05-27 07:00:00
# prediction_day 2018-05-28 07:00:00
# prediction_day 2018-05-29 07:00:00
# prediction_day 2018-05-30 07:00:00
# prediction_day 2018-05-31 07:00:00
# prediction_day 2018-06-01 07:00:00
# prediction_day 2018-06-02 07:00:00
# prediction_day 2018-06-03 07:00:00
# prediction_day 2018-06-04 07:00:00
# prediction_day 2018-06-05 07:00:00
# prediction_day 2018-06-06 07:00:00
# prediction_day 2018-06-07 07:00:00
# prediction_day 2018-06-08 07:00:00
# prediction_day 2018-06-09 07:00:00
# prediction_day 2018-06-10 07:00:00
# prediction_day 2018-06-11 07:00:00
# prediction_day 2018-06-12 07:00:00
# prediction_day 2018-06-13 07:00:00
# prediction_day 2018-06-14 07:00:00
# prediction_day 2018-06-15 07:00:00
# prediction_day 2018-06-16 07:00:00
# prediction_day 2018-06-17 07:00:00
# prediction_day 2018-06-18 07:00:00
# prediction_day 2018-06-19 07:00:00
# prediction_day 2018-06-20 07:00:00
# prediction_day 2018-06-21 07:00:00
# prediction_day 2018-06-22 07:00:00
# prediction_day 2018-06-23 07:00:00
# prediction_day 2018-06-24 07:00:00
# prediction_day 2018-06-25 07:00:00
# prediction_day 2018-06-26 07:00:00
# prediction_day 2018-06-27 07:00:00
# prediction_day 2018-06-28 07:00:00
# prediction_day 2018-06-29 07:00:00
# prediction_day 2018-06-30 07:00:00
# prediction_day 2018-07-01 07:00:00
# prediction_day 2018-07-02 07:00:00
# prediction_day 2018-07-03 07:00:00
# prediction_day 2018-07-04 07:00:00
# prediction_day 2018-07-05 07:00:00
# prediction_day 2018-07-06 07:00:00
# prediction_day 2018-07-07 07:00:00
# prediction_day 2018-07-08 07:00:00
# prediction_day 2018-07-09 07:00:00
# prediction_day 2018-07-10 07:00:00
# prediction_day 2018-07-11 07:00:00
# prediction_day 2018-07-12 07:00:00
# prediction_day 2018-07-13 07:00:00
# prediction_day 2018-07-14 07:00:00
# prediction_day 2018-07-15 07:00:00
# prediction_day 2018-07-16 07:00:00
# prediction_day 2018-07-17 07:00:00
# prediction_day 2018-07-18 07:00:00
# prediction_day 2018-07-19 07:00:00
# prediction_day 2018-07-20 07:00:00
# prediction_day 2018-07-21 07:00:00
# prediction_day 2018-07-22 07:00:00
# prediction_day 2018-07-23 07:00:00
# prediction_day 2018-07-24 07:00:00
# prediction_day 2018-07-25 07:00:00
# prediction_day 2018-07-26 07:00:00
# prediction_day 2018-07-27 07:00:00
# prediction_day 2018-07-28 07:00:00
# prediction_day 2018-07-29 07:00:00
# prediction_day 2018-07-30 07:00:00
# prediction_day 2018-07-31 07:00:00
# prediction_day 2018-08-01 07:00:00
# prediction_day 2018-08-02 07:00:00
# prediction_day 2018-08-03 07:00:00
# prediction_day 2018-08-04 07:00:00
# prediction_day 2018-08-05 07:00:00
# prediction_day 2018-08-06 07:00:00
# prediction_day 2018-08-07 07:00:00
# prediction_day 2018-08-08 07:00:00
# prediction_day 2018-08-09 07:00:00
# prediction_day 2018-08-10 07:00:00
# prediction_day 2018-08-11 07:00:00
# prediction_day 2018-08-12 07:00:00
# prediction_day 2018-08-13 07:00:00
# prediction_day 2018-08-14 07:00:00
# prediction_day 2018-08-15 07:00:00
# prediction_day 2018-08-16 07:00:00
# prediction_day 2018-08-17 07:00:00
# prediction_day 2018-08-18 07:00:00
# prediction_day 2018-08-19 07:00:00
# prediction_day 2018-08-20 07:00:00
# prediction_day 2018-08-21 07:00:00
# prediction_day 2018-08-22 07:00:00
# prediction_day 2018-08-23 07:00:00
# prediction_day 2018-08-24 07:00:00
# prediction_day 2018-08-25 07:00:00
# prediction_day 2018-08-26 07:00:00
# prediction_day 2018-08-27 07:00:00
# prediction_day 2018-08-28 07:00:00
# prediction_day 2018-08-29 07:00:00
# prediction_day 2018-08-30 07:00:00
# prediction_day 2018-08-31 07:00:00
# prediction_day 2018-09-01 07:00:00
# prediction_day 2018-09-02 07:00:00
# prediction_day 2018-09-03 07:00:00
# prediction_day 2018-09-04 07:00:00
# prediction_day 2018-09-05 07:00:00
# prediction_day 2018-09-06 07:00:00
# prediction_day 2018-09-07 07:00:00
# prediction_day 2018-09-08 07:00:00
# prediction_day 2018-09-09 07:00:00
# prediction_day 2018-09-10 07:00:00
# prediction_day 2018-09-11 07:00:00
# prediction_day 2018-09-12 07:00:00
# prediction_day 2018-09-13 07:00:00
# prediction_day 2018-09-14 07:00:00
# prediction_day 2018-09-15 07:00:00
# prediction_day 2018-09-16 07:00:00
# prediction_day 2018-09-17 07:00:00
# prediction_day 2018-09-18 07:00:00
# prediction_day 2018-09-19 07:00:00
# prediction_day 2018-09-20 07:00:00
# prediction_day 2018-09-21 07:00:00
# prediction_day 2018-09-22 07:00:00
# prediction_day 2018-09-23 07:00:00
# prediction_day 2018-09-24 07:00:00
# prediction_day 2018-09-25 07:00:00
# prediction_day 2018-09-26 07:00:00
# prediction_day 2018-09-27 07:00:00
# prediction_day 2018-09-28 07:00:00
# prediction_day 2018-09-29 07:00:00
# prediction_day 2018-09-30 07:00:00
# prediction_day 2018-10-01 07:00:00
# prediction_day 2018-10-02 07:00:00
# prediction_day 2018-10-03 07:00:00
# prediction_day 2018-10-04 07:00:00
# prediction_day 2018-10-05 07:00:00
# prediction_day 2018-10-06 07:00:00
# prediction_day 2018-10-07 07:00:00
# prediction_day 2018-10-08 07:00:00
# prediction_day 2018-10-09 07:00:00
# prediction_day 2018-10-10 07:00:00
# prediction_day 2018-10-11 07:00:00
# prediction_day 2018-10-12 07:00:00
# prediction_day 2018-10-13 07:00:00
# prediction_day 2018-10-14 07:00:00
# prediction_day 2018-10-15 07:00:00
# prediction_day 2018-10-16 07:00:00
# prediction_day 2018-10-17 07:00:00
# prediction_day 2018-10-18 07:00:00
# prediction_day 2018-10-19 07:00:00
# prediction_day 2018-10-20 07:00:00
# prediction_day 2018-10-21 07:00:00
# prediction_day 2018-10-22 07:00:00
# prediction_day 2018-10-23 07:00:00
# prediction_day 2018-10-24 07:00:00
# prediction_day 2018-10-25 07:00:00
# prediction_day 2018-10-26 07:00:00
# prediction_day 2018-10-27 07:00:00
# prediction_day 2018-10-28 07:00:00
# prediction_day 2018-10-29 07:00:00
# prediction_day 2018-10-30 07:00:00
# prediction_day 2018-10-31 07:00:00
# prediction_day 2018-11-01 07:00:00
# prediction_day 2018-11-02 07:00:00
# prediction_day 2018-11-03 07:00:00
# prediction_day 2018-11-04 07:00:00
# prediction_day 2018-11-05 07:00:00
# prediction_day 2018-11-06 07:00:00
# prediction_day 2018-11-07 07:00:00
# prediction_day 2018-11-08 07:00:00
# prediction_day 2018-11-09 07:00:00
# prediction_day 2018-11-10 07:00:00
# prediction_day 2018-11-11 07:00:00
# prediction_day 2018-11-12 07:00:00
# prediction_day 2018-11-13 07:00:00
# prediction_day 2018-11-14 07:00:00
# prediction_day 2018-11-15 07:00:00
# prediction_day 2018-11-16 07:00:00
# prediction_day 2018-11-17 07:00:00
# prediction_day 2018-11-18 07:00:00
# prediction_day 2018-11-19 07:00:00
# prediction_day 2018-11-20 07:00:00
# prediction_day 2018-11-21 07:00:00
# prediction_day 2018-11-22 07:00:00
# prediction_day 2018-11-23 07:00:00
# prediction_day 2018-11-24 07:00:00
# prediction_day 2018-11-25 07:00:00
# prediction_day 2018-11-26 07:00:00
# prediction_day 2018-11-27 07:00:00
# prediction_day 2018-11-28 07:00:00
# prediction_day 2018-11-29 07:00:00
# prediction_day 2018-11-30 07:00:00
# prediction_day 2018-12-01 07:00:00
# prediction_day 2018-12-02 07:00:00
# prediction_day 2018-12-03 07:00:00
# prediction_day 2018-12-04 07:00:00
# prediction_day 2018-12-05 07:00:00
# prediction_day 2018-12-06 07:00:00
# prediction_day 2018-12-07 07:00:00
# prediction_day 2018-12-08 07:00:00
# prediction_day 2018-12-09 07:00:00
# prediction_day 2018-12-10 07:00:00
# prediction_day 2018-12-11 07:00:00
# prediction_day 2018-12-12 07:00:00
# prediction_day 2018-12-13 07:00:00
# prediction_day 2018-12-14 07:00:00
# prediction_day 2018-12-15 07:00:00
# prediction_day 2018-12-16 07:00:00
# prediction_day 2018-12-17 07:00:00
# prediction_day 2018-12-18 07:00:00
# prediction_day 2018-12-19 07:00:00
# prediction_day 2018-12-20 07:00:00
# prediction_day 2018-12-21 07:00:00
# prediction_day 2018-12-22 07:00:00
# prediction_day 2018-12-23 07:00:00
# prediction_day 2018-12-24 07:00:00
# prediction_day 2018-12-25 07:00:00
# prediction_day 2018-12-26 07:00:00
# prediction_day 2018-12-27 07:00:00
# prediction_day 2018-12-28 07:00:00
# prediction_day 2018-12-29 07:00:00
# prediction_day 2018-12-30 07:00:00
# prediction_day 2018-12-31 07:00:00
# mape 2.5550421657100904

# %% [markdown]
# ## Prophet

# %%
timeHorizon = 48
startDay = pd.to_datetime('2017-12-02 07:00:00')

for i in range(n_days):

    last_known_day = (startDay + pd.DateOffset(days=30+i))
    prediction_day = (last_known_day + pd.DateOffset(days=1))
    last_prediction_day = str((prediction_day + pd.DateOffset(days=1)))
    
    print('prediction_day (offset 1d)',prediction_day)
    
    df = data[['Load (kW)']]
    df['ds'] = df.index
    df['y'] = df['Load (kW)']
    df=df.drop(columns = ['Load (kW)'])
    
    df=df.loc[startDay:last_known_day]
    
#     print(df)
    
    df['temp'] = (data['Temperature (C) '].loc[startDay:last_known_day]).values
    df['wind_speed'] = (data['Wind Speed (kmh)'].loc[startDay:last_known_day]).values
    df['cloud'] = (data['Cloud Cover (%)'].loc[startDay:last_known_day]).values
    df['wind_direction'] = (data['Wind Direction (deg)'].loc[startDay:last_known_day]).values
    df['pressure'] = (data['Pressure_kpa'].loc[startDay:last_known_day]).values
    df['day_of_week'] = (data['day_of_week'].loc[startDay:last_known_day]).values
    df['time_of_day'] = (data['time_of_day'].loc[startDay:last_known_day]).values
    df['is_weekend'] = (data['is_weekend'].loc[startDay:last_known_day]).values
    
    m = Prophet(daily_seasonality=40, weekly_seasonality=80, changepoint_prior_scale=0.003, yearly_seasonality=False, seasonality_mode='multiplicative', changepoint_range=.9) #, seasonality_prior_scale=100)
#     m = Prophet()
    
    m.add_regressor('temp')
    m.add_regressor('wind_speed')
    m.add_regressor('cloud')
    m.add_regressor('wind_direction')
    m.add_regressor('pressure')
    m.add_regressor('day_of_week')
    m.add_regressor('time_of_day')
    m.add_regressor('is_weekend')
    
    metrics = m.fit(df)
    
    future = m.make_future_dataframe(periods=timeHorizon, freq='1h')
    
#     print(future)
#     print(startDay*samplingFreq+i*samplingFreq-startDay*samplingFreq-28*samplingFreq)
    
    future['temp'] = (data['Temperature (C) '].loc[startDay:last_prediction_day]).values
    future['wind_speed'] = (data['Wind Speed (kmh)'].loc[startDay:last_prediction_day]).values
    future['cloud'] = (data['Cloud Cover (%)'].loc[startDay:last_prediction_day]).values
    future['wind_direction'] = (data['Wind Direction (deg)'].loc[startDay:last_prediction_day]).values
    future['pressure'] = (data['Pressure_kpa'].loc[startDay:last_prediction_day]).values
    future['day_of_week'] = (data['day_of_week'].loc[startDay:last_prediction_day]).values
    future['time_of_day'] = (data['time_of_day'].loc[startDay:last_prediction_day]).values
    future['is_weekend'] = (data['is_weekend'].loc[startDay:last_prediction_day]).values
    
    #prophetMatrix[i] = m.predict(future).yhat.iloc[-32:-8]
    overall_pred.loc[future.ds[-32:-8], 'Prophet'] = m.predict(future).yhat.iloc[-32:-8].values
# Out:
# prediction_day (offset 1d) 2018-01-02 07:00:00
# prediction_day (offset 1d) 2018-01-03 07:00:00
# prediction_day (offset 1d) 2018-01-04 07:00:00
# prediction_day (offset 1d) 2018-01-05 07:00:00
# prediction_day (offset 1d) 2018-01-06 07:00:00
# prediction_day (offset 1d) 2018-01-07 07:00:00
# prediction_day (offset 1d) 2018-01-08 07:00:00
# prediction_day (offset 1d) 2018-01-09 07:00:00
# prediction_day (offset 1d) 2018-01-10 07:00:00
# prediction_day (offset 1d) 2018-01-11 07:00:00
# prediction_day (offset 1d) 2018-01-12 07:00:00
# prediction_day (offset 1d) 2018-01-13 07:00:00
# prediction_day (offset 1d) 2018-01-14 07:00:00
# prediction_day (offset 1d) 2018-01-15 07:00:00
# prediction_day (offset 1d) 2018-01-16 07:00:00
# prediction_day (offset 1d) 2018-01-17 07:00:00
# prediction_day (offset 1d) 2018-01-18 07:00:00
# prediction_day (offset 1d) 2018-01-19 07:00:00
# prediction_day (offset 1d) 2018-01-20 07:00:00
# prediction_day (offset 1d) 2018-01-21 07:00:00
# prediction_day (offset 1d) 2018-01-22 07:00:00
# prediction_day (offset 1d) 2018-01-23 07:00:00
# prediction_day (offset 1d) 2018-01-24 07:00:00
# prediction_day (offset 1d) 2018-01-25 07:00:00
# prediction_day (offset 1d) 2018-01-26 07:00:00
# prediction_day (offset 1d) 2018-01-27 07:00:00
# prediction_day (offset 1d) 2018-01-28 07:00:00
# prediction_day (offset 1d) 2018-01-29 07:00:00
# prediction_day (offset 1d) 2018-01-30 07:00:00
# prediction_day (offset 1d) 2018-01-31 07:00:00
# prediction_day (offset 1d) 2018-02-01 07:00:00
# prediction_day (offset 1d) 2018-02-02 07:00:00
# prediction_day (offset 1d) 2018-02-03 07:00:00
# prediction_day (offset 1d) 2018-02-04 07:00:00
# prediction_day (offset 1d) 2018-02-05 07:00:00
# prediction_day (offset 1d) 2018-02-06 07:00:00
# prediction_day (offset 1d) 2018-02-07 07:00:00
# prediction_day (offset 1d) 2018-02-08 07:00:00
# prediction_day (offset 1d) 2018-02-09 07:00:00
# prediction_day (offset 1d) 2018-02-10 07:00:00
# prediction_day (offset 1d) 2018-02-11 07:00:00
# prediction_day (offset 1d) 2018-02-12 07:00:00
# prediction_day (offset 1d) 2018-02-13 07:00:00
# prediction_day (offset 1d) 2018-02-14 07:00:00
# prediction_day (offset 1d) 2018-02-15 07:00:00
# prediction_day (offset 1d) 2018-02-16 07:00:00
# prediction_day (offset 1d) 2018-02-17 07:00:00
# prediction_day (offset 1d) 2018-02-18 07:00:00
# prediction_day (offset 1d) 2018-02-19 07:00:00
# prediction_day (offset 1d) 2018-02-20 07:00:00
# prediction_day (offset 1d) 2018-02-21 07:00:00
# prediction_day (offset 1d) 2018-02-22 07:00:00
# prediction_day (offset 1d) 2018-02-23 07:00:00
# prediction_day (offset 1d) 2018-02-24 07:00:00
# prediction_day (offset 1d) 2018-02-25 07:00:00
# prediction_day (offset 1d) 2018-02-26 07:00:00
# prediction_day (offset 1d) 2018-02-27 07:00:00
# prediction_day (offset 1d) 2018-02-28 07:00:00
# prediction_day (offset 1d) 2018-03-01 07:00:00
# prediction_day (offset 1d) 2018-03-02 07:00:00
# prediction_day (offset 1d) 2018-03-03 07:00:00
# prediction_day (offset 1d) 2018-03-04 07:00:00
# prediction_day (offset 1d) 2018-03-05 07:00:00
# prediction_day (offset 1d) 2018-03-06 07:00:00
# prediction_day (offset 1d) 2018-03-07 07:00:00
# prediction_day (offset 1d) 2018-03-08 07:00:00
# prediction_day (offset 1d) 2018-03-09 07:00:00
# prediction_day (offset 1d) 2018-03-10 07:00:00
# prediction_day (offset 1d) 2018-03-11 07:00:00
# prediction_day (offset 1d) 2018-03-12 07:00:00
# prediction_day (offset 1d) 2018-03-13 07:00:00
# prediction_day (offset 1d) 2018-03-14 07:00:00
# prediction_day (offset 1d) 2018-03-15 07:00:00
# prediction_day (offset 1d) 2018-03-16 07:00:00
# prediction_day (offset 1d) 2018-03-17 07:00:00
# prediction_day (offset 1d) 2018-03-18 07:00:00
# prediction_day (offset 1d) 2018-03-19 07:00:00
# prediction_day (offset 1d) 2018-03-20 07:00:00
# prediction_day (offset 1d) 2018-03-21 07:00:00
# prediction_day (offset 1d) 2018-03-22 07:00:00
# prediction_day (offset 1d) 2018-03-23 07:00:00
# prediction_day (offset 1d) 2018-03-24 07:00:00
# prediction_day (offset 1d) 2018-03-25 07:00:00
# prediction_day (offset 1d) 2018-03-26 07:00:00
# prediction_day (offset 1d) 2018-03-27 07:00:00
# prediction_day (offset 1d) 2018-03-28 07:00:00
# prediction_day (offset 1d) 2018-03-29 07:00:00
# prediction_day (offset 1d) 2018-03-30 07:00:00
# prediction_day (offset 1d) 2018-03-31 07:00:00
# prediction_day (offset 1d) 2018-04-01 07:00:00
# prediction_day (offset 1d) 2018-04-02 07:00:00
# prediction_day (offset 1d) 2018-04-03 07:00:00
# prediction_day (offset 1d) 2018-04-04 07:00:00
# prediction_day (offset 1d) 2018-04-05 07:00:00
# prediction_day (offset 1d) 2018-04-06 07:00:00
# prediction_day (offset 1d) 2018-04-07 07:00:00
# prediction_day (offset 1d) 2018-04-08 07:00:00
# prediction_day (offset 1d) 2018-04-09 07:00:00
# prediction_day (offset 1d) 2018-04-10 07:00:00
# prediction_day (offset 1d) 2018-04-11 07:00:00
# prediction_day (offset 1d) 2018-04-12 07:00:00
# prediction_day (offset 1d) 2018-04-13 07:00:00
# prediction_day (offset 1d) 2018-04-14 07:00:00
# prediction_day (offset 1d) 2018-04-15 07:00:00
# prediction_day (offset 1d) 2018-04-16 07:00:00
# prediction_day (offset 1d) 2018-04-17 07:00:00
# prediction_day (offset 1d) 2018-04-18 07:00:00
# prediction_day (offset 1d) 2018-04-19 07:00:00
# prediction_day (offset 1d) 2018-04-20 07:00:00
# prediction_day (offset 1d) 2018-04-21 07:00:00
# prediction_day (offset 1d) 2018-04-22 07:00:00
# prediction_day (offset 1d) 2018-04-23 07:00:00
# prediction_day (offset 1d) 2018-04-24 07:00:00
# prediction_day (offset 1d) 2018-04-25 07:00:00
# prediction_day (offset 1d) 2018-04-26 07:00:00
# prediction_day (offset 1d) 2018-04-27 07:00:00
# prediction_day (offset 1d) 2018-04-28 07:00:00
# prediction_day (offset 1d) 2018-04-29 07:00:00
# prediction_day (offset 1d) 2018-04-30 07:00:00
# prediction_day (offset 1d) 2018-05-01 07:00:00
# prediction_day (offset 1d) 2018-05-02 07:00:00
# prediction_day (offset 1d) 2018-05-03 07:00:00
# prediction_day (offset 1d) 2018-05-04 07:00:00
# prediction_day (offset 1d) 2018-05-05 07:00:00
# prediction_day (offset 1d) 2018-05-06 07:00:00
# prediction_day (offset 1d) 2018-05-07 07:00:00
# prediction_day (offset 1d) 2018-05-08 07:00:00
# prediction_day (offset 1d) 2018-05-09 07:00:00
# prediction_day (offset 1d) 2018-05-10 07:00:00
# prediction_day (offset 1d) 2018-05-11 07:00:00
# prediction_day (offset 1d) 2018-05-12 07:00:00
# prediction_day (offset 1d) 2018-05-13 07:00:00
# prediction_day (offset 1d) 2018-05-14 07:00:00
# prediction_day (offset 1d) 2018-05-15 07:00:00
# prediction_day (offset 1d) 2018-05-16 07:00:00
# prediction_day (offset 1d) 2018-05-17 07:00:00
# prediction_day (offset 1d) 2018-05-18 07:00:00
# prediction_day (offset 1d) 2018-05-19 07:00:00
# prediction_day (offset 1d) 2018-05-20 07:00:00
# prediction_day (offset 1d) 2018-05-21 07:00:00
# prediction_day (offset 1d) 2018-05-22 07:00:00
# prediction_day (offset 1d) 2018-05-23 07:00:00
# prediction_day (offset 1d) 2018-05-24 07:00:00
# prediction_day (offset 1d) 2018-05-25 07:00:00
# prediction_day (offset 1d) 2018-05-26 07:00:00
# prediction_day (offset 1d) 2018-05-27 07:00:00
# prediction_day (offset 1d) 2018-05-28 07:00:00
# prediction_day (offset 1d) 2018-05-29 07:00:00
# prediction_day (offset 1d) 2018-05-30 07:00:00
# prediction_day (offset 1d) 2018-05-31 07:00:00
# prediction_day (offset 1d) 2018-06-01 07:00:00
# prediction_day (offset 1d) 2018-06-02 07:00:00
# prediction_day (offset 1d) 2018-06-03 07:00:00
# prediction_day (offset 1d) 2018-06-04 07:00:00
# prediction_day (offset 1d) 2018-06-05 07:00:00
# prediction_day (offset 1d) 2018-06-06 07:00:00
# prediction_day (offset 1d) 2018-06-07 07:00:00
# prediction_day (offset 1d) 2018-06-08 07:00:00
# prediction_day (offset 1d) 2018-06-09 07:00:00
# prediction_day (offset 1d) 2018-06-10 07:00:00
# prediction_day (offset 1d) 2018-06-11 07:00:00
# prediction_day (offset 1d) 2018-06-12 07:00:00
# prediction_day (offset 1d) 2018-06-13 07:00:00
# prediction_day (offset 1d) 2018-06-14 07:00:00
# prediction_day (offset 1d) 2018-06-15 07:00:00
# prediction_day (offset 1d) 2018-06-16 07:00:00
# prediction_day (offset 1d) 2018-06-17 07:00:00
# prediction_day (offset 1d) 2018-06-18 07:00:00
# prediction_day (offset 1d) 2018-06-19 07:00:00
# prediction_day (offset 1d) 2018-06-20 07:00:00
# prediction_day (offset 1d) 2018-06-21 07:00:00
# prediction_day (offset 1d) 2018-06-22 07:00:00
# prediction_day (offset 1d) 2018-06-23 07:00:00
# prediction_day (offset 1d) 2018-06-24 07:00:00
# prediction_day (offset 1d) 2018-06-25 07:00:00
# prediction_day (offset 1d) 2018-06-26 07:00:00
# prediction_day (offset 1d) 2018-06-27 07:00:00
# prediction_day (offset 1d) 2018-06-28 07:00:00
# prediction_day (offset 1d) 2018-06-29 07:00:00
# prediction_day (offset 1d) 2018-06-30 07:00:00
# prediction_day (offset 1d) 2018-07-01 07:00:00
# prediction_day (offset 1d) 2018-07-02 07:00:00
# prediction_day (offset 1d) 2018-07-03 07:00:00
# prediction_day (offset 1d) 2018-07-04 07:00:00
# prediction_day (offset 1d) 2018-07-05 07:00:00
# prediction_day (offset 1d) 2018-07-06 07:00:00
# prediction_day (offset 1d) 2018-07-07 07:00:00
# prediction_day (offset 1d) 2018-07-08 07:00:00
# prediction_day (offset 1d) 2018-07-09 07:00:00
# prediction_day (offset 1d) 2018-07-10 07:00:00
# prediction_day (offset 1d) 2018-07-11 07:00:00
# prediction_day (offset 1d) 2018-07-12 07:00:00
# prediction_day (offset 1d) 2018-07-13 07:00:00
# prediction_day (offset 1d) 2018-07-14 07:00:00
# prediction_day (offset 1d) 2018-07-15 07:00:00
# prediction_day (offset 1d) 2018-07-16 07:00:00
# prediction_day (offset 1d) 2018-07-17 07:00:00
# prediction_day (offset 1d) 2018-07-18 07:00:00
# prediction_day (offset 1d) 2018-07-19 07:00:00
# prediction_day (offset 1d) 2018-07-20 07:00:00
# prediction_day (offset 1d) 2018-07-21 07:00:00
# prediction_day (offset 1d) 2018-07-22 07:00:00
# prediction_day (offset 1d) 2018-07-23 07:00:00
# prediction_day (offset 1d) 2018-07-24 07:00:00
# prediction_day (offset 1d) 2018-07-25 07:00:00
# prediction_day (offset 1d) 2018-07-26 07:00:00
# prediction_day (offset 1d) 2018-07-27 07:00:00
# prediction_day (offset 1d) 2018-07-28 07:00:00
# prediction_day (offset 1d) 2018-07-29 07:00:00
# prediction_day (offset 1d) 2018-07-30 07:00:00
# prediction_day (offset 1d) 2018-07-31 07:00:00
# prediction_day (offset 1d) 2018-08-01 07:00:00
# prediction_day (offset 1d) 2018-08-02 07:00:00
# prediction_day (offset 1d) 2018-08-03 07:00:00
# prediction_day (offset 1d) 2018-08-04 07:00:00
# prediction_day (offset 1d) 2018-08-05 07:00:00
# prediction_day (offset 1d) 2018-08-06 07:00:00
# prediction_day (offset 1d) 2018-08-07 07:00:00
# prediction_day (offset 1d) 2018-08-08 07:00:00
# prediction_day (offset 1d) 2018-08-09 07:00:00
# prediction_day (offset 1d) 2018-08-10 07:00:00
# prediction_day (offset 1d) 2018-08-11 07:00:00
# prediction_day (offset 1d) 2018-08-12 07:00:00
# prediction_day (offset 1d) 2018-08-13 07:00:00
# prediction_day (offset 1d) 2018-08-14 07:00:00
# prediction_day (offset 1d) 2018-08-15 07:00:00
# prediction_day (offset 1d) 2018-08-16 07:00:00
# prediction_day (offset 1d) 2018-08-17 07:00:00
# prediction_day (offset 1d) 2018-08-18 07:00:00
# prediction_day (offset 1d) 2018-08-19 07:00:00
# prediction_day (offset 1d) 2018-08-20 07:00:00
# prediction_day (offset 1d) 2018-08-21 07:00:00
# prediction_day (offset 1d) 2018-08-22 07:00:00
# prediction_day (offset 1d) 2018-08-23 07:00:00
# prediction_day (offset 1d) 2018-08-24 07:00:00
# prediction_day (offset 1d) 2018-08-25 07:00:00
# prediction_day (offset 1d) 2018-08-26 07:00:00
# prediction_day (offset 1d) 2018-08-27 07:00:00
# prediction_day (offset 1d) 2018-08-28 07:00:00
# prediction_day (offset 1d) 2018-08-29 07:00:00
# prediction_day (offset 1d) 2018-08-30 07:00:00
# prediction_day (offset 1d) 2018-08-31 07:00:00
# prediction_day (offset 1d) 2018-09-01 07:00:00
# prediction_day (offset 1d) 2018-09-02 07:00:00
# prediction_day (offset 1d) 2018-09-03 07:00:00
# prediction_day (offset 1d) 2018-09-04 07:00:00
# prediction_day (offset 1d) 2018-09-05 07:00:00
# prediction_day (offset 1d) 2018-09-06 07:00:00
# prediction_day (offset 1d) 2018-09-07 07:00:00
# prediction_day (offset 1d) 2018-09-08 07:00:00
# prediction_day (offset 1d) 2018-09-09 07:00:00
# prediction_day (offset 1d) 2018-09-10 07:00:00
# prediction_day (offset 1d) 2018-09-11 07:00:00
# prediction_day (offset 1d) 2018-09-12 07:00:00
# prediction_day (offset 1d) 2018-09-13 07:00:00
# prediction_day (offset 1d) 2018-09-14 07:00:00
# prediction_day (offset 1d) 2018-09-15 07:00:00
# prediction_day (offset 1d) 2018-09-16 07:00:00
# prediction_day (offset 1d) 2018-09-17 07:00:00
# prediction_day (offset 1d) 2018-09-18 07:00:00
# prediction_day (offset 1d) 2018-09-19 07:00:00
# prediction_day (offset 1d) 2018-09-20 07:00:00
# prediction_day (offset 1d) 2018-09-21 07:00:00
# prediction_day (offset 1d) 2018-09-22 07:00:00
# prediction_day (offset 1d) 2018-09-23 07:00:00
# prediction_day (offset 1d) 2018-09-24 07:00:00
# prediction_day (offset 1d) 2018-09-25 07:00:00
# prediction_day (offset 1d) 2018-09-26 07:00:00
# prediction_day (offset 1d) 2018-09-27 07:00:00

# %%
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['Prophet'].values, label='pred')
plt.legend()
plt.show()
print('mape',overall_mape.mean())

# %% [markdown]
# # Create prediction for N days: LR

# %%
data = data.drop(['Pressure_kpa','Temperature (C) ','Cloud Cover (%)','Wind Direction (deg)','Wind Speed (kmh)'],axis=1)
lags_df = add_lag_features(data,lags)

# %%
model = linear_model.LinearRegression() # Create a linear model object

overall_mape = np.zeros(n_days)
start_day = pd.to_datetime('2017-12-01 07:00:00')

for i in range(n_days):

    last_known_day = (start_day + pd.DateOffset(days=30+i))#.date()
    prediction_day = (last_known_day + pd.DateOffset(days=1))#.date()
    last_prediction_day = str((prediction_day + pd.DateOffset(days=1)))#.date())
    print('prediction_day',prediction_day)

    pred = create_prediction(model, start_day=start_day, last_known_day=last_known_day, 
                             prediction_day=prediction_day, last_prediction_day=prediction_day, 
                             horizon = 41)
    
    prediction = pred.dropna()['Load (kW)'].values[17:41]
    fact = data.loc[pred.dropna().index,'Load (kW)'].values[17:41]

    overall_mape[i] = 100 * np.mean(np.abs(prediction - fact)) / np.mean(np.abs(fact))
    
    overall_pred.loc[pred.index[17:41], 'LR Model'] = pred['Load (kW)'].iloc[17:41]
    
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['LR Model'].values, label='pred')
plt.legend()
plt.show()
print('mape',overall_mape.mean())

# %%
overall_pred.dropna()

# %% [markdown]
# # Make theta prediction

# %%
def make_theta_prediction(theta_model, start_day, last_known_day, prediction_day, last_prediction_day, horizon):
    
    series = TimeSeries.from_dataframe(pd.DataFrame(data.loc[start_day:last_prediction_day, 'Load (kW)'])) #TimeSeries.from_dataframe(data.reset_index().iloc[start_time-28*24:start_time+nhorizon], 'Time', 'Load (kW)')        
    train, val = series.split_after(pd.Timestamp(last_known_day))
    theta_model.fit(train)
    return theta_model.predict(horizon)

# %%
n_horizon = 41
theta_model = Theta(1)
start_day = pd.to_datetime('2017-12-01 07:00:00')

for i in range(n_days):

    last_known_day = (start_day + pd.DateOffset(days=30+i))#.date()
    prediction_day = (last_known_day + pd.DateOffset(days=1))#.date()
    last_prediction_day = str((prediction_day + pd.DateOffset(days=1)))#.date())
    print('prediction_day',prediction_day)
    
    pred = make_theta_prediction(theta_model,
                                   start_day=start_day, 
                                   last_known_day=last_known_day, 
                                   prediction_day=prediction_day, 
                                   last_prediction_day=last_prediction_day, 
                                   horizon=n_horizon)
        
    overall_pred.loc[pred.time_index()[16:40], 'Theta Model'] = pred[16:40].values()
    
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['Theta Model'].values, label='pred')
plt.legend()
plt.show()
print('mape',overall_mape.mean())

# %%
overall_pred['LR Model'].dropna()#.plot()#.values[:-40]

# %% [markdown]
# # Comparing models

# %%
prophet_prediction = overall_pred['Prophet'].dropna().values[:-40]
fact = data.loc[overall_pred['Prophet'].dropna().index,'Load (kW)'].values[:-40]
linearNoWeather_prediction = overall_pred['LR Model'].dropna().values[:-40]
cb_prediction = overall_pred['CB Model'].dropna().values[:-40]
theta_prediction = overall_pred['Theta Model'].dropna().values[:-40]
#direct_rf_prediction = overall_pred['Direct RF Model'].dropna().values[:-40]
persistence_7d = data.loc[overall_pred['Prophet'].dropna().index + pd.DateOffset(days=-7),'Load (kW)'].values[:-40]
#persistence_1d = data.loc[overall_pred.dropna().index + pd.DateOffset(days=-1),'Load (kW)'].values

error = prophet_prediction*.225 + cb_prediction*.225 + theta_prediction*.05 + linearNoWeather_prediction*.5 - fact
plt.plot(error)
plt.show()

mape_prophet = 100 * np.mean(np.abs(prophet_prediction - fact)) / np.mean(np.abs(fact))
mape_cb = 100 * np.mean(np.abs(cb_prediction - fact)) / np.mean(np.abs(fact))
mape_lin = 100 * np.mean(np.abs(linearNoWeather_prediction - fact)) / np.mean(np.abs(fact))
mape_theta = 100 * np.mean(np.abs(theta_prediction - fact)) / np.mean(np.abs(fact))
#mape_direct_rf = 100 * np.mean(np.abs(direct_rf_prediction - fact)) / np.mean(np.abs(fact))

mape_comb_1 = 100 * np.mean(np.abs(prophet_prediction*.5 + .5*cb_prediction - fact)) / np.mean(np.abs(fact))
mape_comb_2 = 100 * np.mean(np.abs(prophet_prediction*.5 + .5*linearNoWeather_prediction - fact)) / np.mean(np.abs(fact))
mape_comb_3 = 100 * np.mean(np.abs(cb_prediction*.5 + .5*linearNoWeather_prediction - fact)) / np.mean(np.abs(fact))
mape_comb_4 = 100 * np.mean(np.abs(prophet_prediction/5 + cb_prediction/5 + linearNoWeather_prediction*3/5 - fact)) / np.mean(np.abs(fact))
mape_comb_5 = 100 * np.mean(np.abs(prophet_prediction*.25 + cb_prediction*.25 + theta_prediction*.05 + linearNoWeather_prediction*.45 - fact)) / np.mean(np.abs(fact))
mape_comb_5m = 100 * np.mean(np.abs(prophet_prediction*.25 + cb_prediction*.25 + theta_prediction*.25 + linearNoWeather_prediction*.25 - fact)) / np.mean(np.abs(fact))
mape_comb_5p = 100 * np.mean(np.abs(persistence_7d*.1 + prophet_prediction*.2 + cb_prediction*.2 + theta_prediction*.05 + linearNoWeather_prediction*.45 - fact)) / np.mean(np.abs(fact))
mape_persistence_7d = 100 * np.mean(np.abs(persistence_7d - fact)) / np.mean(np.abs(fact))
#mape_persistence_1d = 100 * np.mean(np.abs(persistence_1d - fact)) / np.mean(np.abs(fact))

mape_comb_6 = 100 * np.mean(np.abs(prophet_prediction*.35 + theta_prediction*.05 + linearNoWeather_prediction*.6 - fact)) / np.mean(np.abs(fact))


print('mape Pr:', mape_prophet)
print('mape CB:', mape_cb)
print('mape Linear:', mape_lin)
print('mape Theta:', mape_theta)
#print('mape Direct RF:', mape_direct_rf)

print('mape comb 1:', mape_comb_1)
print('mape comb 2:', mape_comb_2)
print('mape comb 3:', mape_comb_3)
print('mape comb 4 (all - theta):', mape_comb_4)
print('mape comb 5 (all weighted mean):', mape_comb_5)
print('mape comb 5 (all weighted mean + persistence):', mape_comb_5p)
print('mape comb 5 (all mean):', mape_comb_5m)
print('mape comb 6 (no CB):', mape_comb_6)
print('mape pers 7d:', mape_persistence_7d)
# print('mape pers 1d:', mape_persistence_1d)

plt.scatter(prophet_prediction, linearNoWeather_prediction, alpha=0.3)
plt.scatter(fact, linearNoWeather_prediction, alpha=0.3)
plt.scatter(fact, prophet_prediction, alpha=0.3)
plt.show()

plt.plot(sm.tsa.stattools.acf(error,nlags=200), '*--')
plt.show()

# error2D = (error.reshape((nDays,24))).astype(int)
# print(error2D)
# plt.imshow(error2D)
# plt.show()

# plt.boxplot(error2D,1)
# plt.plot(range(1,25), np.mean(error2D,0))
# plt.show()

print(np.corrcoef(prophet_prediction, fact))
print(np.corrcoef(linearNoWeather_prediction.astype('float'), fact))
print(np.corrcoef(cb_prediction.astype('float'), fact))
print(np.corrcoef(theta_prediction, fact))
#print(np.corrcoef(direct_rf_prediction, fact))

# %% [markdown]
# # Direct prediction for residuals

# %%
res_X_train = overall_pred.dropna()
res_X_train['Final_model']= res_X_train['Prophet']*.3+res_X_train['CB Model']*.2+res_X_train['Theta Model']*.05+res_X_train['LR Model']*.45
res_y_train = pd.DataFrame(data.loc[res_X_train.index,'Load (kW)'] - res_X_train['Final_model'], columns=['Error'])

# %%
#res_X_val.shape, res_X_train.shape, res_y_train.shape
res_y_train.to_csv('Errors.csv')

# %%
res_X_train.join(data[['day_of_week','time_of_day','is_weekend']])
# Out:
#                            CB Model       Prophet        LR Model  \
# Time
# 2020-11-30 00:00:00  1005029.809436  1.016580e+06   982748.037783
# 2020-11-30 01:00:00   994634.277259  1.001871e+06   971816.234104
# 2020-11-30 02:00:00   982649.572027  9.955556e+05     965111.8945
# 2020-11-30 03:00:00   974779.798124  9.898982e+05     960060.1675
# 2020-11-30 04:00:00   970669.365414  9.904296e+05   962045.838117
# ...                             ...           ...             ...
# 2021-02-01 19:00:00  1137985.262995  1.110262e+06  1135837.905137
# 2021-02-01 20:00:00  1105198.847343  1.075127e+06  1101771.096285
# 2021-02-01 21:00:00  1077237.669547  1.047873e+06  1070268.744947
# 2021-02-01 22:00:00  1047366.956202  1.027532e+06  1041861.318998
# 2021-02-01 23:00:00  1020260.945473  1.002143e+06  1014071.783667
#
#                       Theta Model     Final_model  day_of_week  time_of_day  \
# Time
# 2020-11-30 00:00:00  9.721232e+05   996822.862296            0            0
# 2020-11-30 01:00:00  9.574824e+05   984679.539705            0            1
# 2020-11-30 02:00:00  9.456048e+05   976777.189536            0            2
# 2020-11-30 03:00:00  9.368473e+05   970794.865641            0            3
# 2020-11-30 04:00:00  9.342651e+05   970896.620878            0            4
# ...                           ...             ...          ...          ...
# 2021-02-01 19:00:00  1.082818e+06  1125943.463876            0           19
# 2021-02-01 20:00:00  1.058967e+06  1092323.234002            0           20
# 2021-02-01 21:00:00  1.035105e+06  1063185.505275            0           21
# 2021-02-01 22:00:00  1.012156e+06  1037178.336902            0           22
# 2021-02-01 23:00:00  9.850585e+05  1010280.321987            0           23
#
#                      is_weekend
# Time
# 2020-11-30 00:00:00       False
# 2020-11-30 01:00:00       False
# 2020-11-30 02:00:00       False
# 2020-11-30 03:00:00       False
# 2020-11-30 04:00:00       False
# ...                         ...
# 2021-02-01 19:00:00       False
# 2021-02-01 20:00:00       False
# 2021-02-01 21:00:00       False
# 2021-02-01 22:00:00       False
# 2021-02-01 23:00:00       False
#
# [1536 rows x 8 columns]

# %%
def create_direct_prediction(model_name,start_day='2020-10-15', 
                             last_known_day='2020-12-16',
                             prediction_day='2020-12-17'):    
    
    #start=time.time()
    
    y_train = pd.DataFrame(res_y_train.loc[start_day:last_known_day,'Error'])
    X_train = pd.DataFrame(res_X_train.loc[start_day:last_known_day,'Final_model'])
    
    for i in range(16,40):
        y_train['error_'+str(i)] = y_train['Error'].shift(-i).astype('float64')
        X_train['model_'+str(i)] = X_train['Final_model'].shift(-i).astype('float64')
    
    y_train = y_train.dropna().drop(['Error'], axis=1)
    X_train = X_train.dropna().drop(['Final_model'], axis=1).join(data[['day_of_week','time_of_day','is_weekend']])

    #print('y_train',y_train)
    #print('X_train',X_train)
    
    model_name.fit(X_train,y_train)
    
    step = pd.date_range(start=prediction_day, periods=40, freq='H')

    X_pred = pd.DataFrame(res_X_train.loc[step,'Final_model'])
    for i in range(16,40):
        X_pred['model_'+str(i)] = X_pred['Final_model'].shift(-i).astype('float64')
    X_pred = X_pred.dropna().drop(['Final_model'], axis=1).join(data[['day_of_week','time_of_day','is_weekend']])
    
    prediction = model.predict(X_pred)[0]
    #print(X_pred)
    #print('Predict: ', time.time()-start)
    
    return prediction

#model = MultiOutputRegressor(lgb.LGBMRegressor())

#create_direct_prediction(model)
# Out:
# array([-30518.43837614, -25995.48565061, -17925.16317026,  -4028.46071437,
#         -4743.57721435,  -5176.68842988,  -1102.36628272,  -5385.48620409,
#         -6269.32065293,  -5208.00775233,  -4245.62322909,  -8327.62999744,
#         -9371.06927231, -13511.89253863,  -4498.43411314,  -2534.46849386,
#         -9722.36391696, -12192.70301312, -27522.13025411, -23071.55161333,
#        -20423.87592876,  -2090.55441288,  -9724.16565092, -11467.29385907])

# %%
overall_pred.dropna()
# Out:
#                            CB Model       Prophet        LR Model  \
# Time
# 2021-01-14 00:00:00   984048.234641  9.797530e+05   961874.977727
# 2021-01-14 01:00:00   973497.768961  9.663572e+05   948099.209725
# 2021-01-14 02:00:00   964137.206781  9.548862e+05   939339.376904
# 2021-01-14 03:00:00   958505.027843  9.489888e+05   931279.982691
# 2021-01-14 04:00:00   958478.966186  9.462485e+05   930478.556856
# ...                             ...           ...             ...
# 2021-01-30 19:00:00  1107491.539873  1.105618e+06  1106675.329756
# 2021-01-30 20:00:00  1084215.815906  1.081692e+06  1083672.250551
# 2021-01-30 21:00:00  1058051.729725  1.057481e+06  1059750.740654
# 2021-01-30 22:00:00  1033391.085025  1.034657e+06  1034969.555995
# 2021-01-30 23:00:00   1013551.79978  1.007804e+06  1009144.736898
#
#                       Theta Model  Direct Error Model
# Time
# 2021-01-14 00:00:00  1.014539e+06        -5820.910408
# 2021-01-14 01:00:00  1.000294e+06        -4301.584809
# 2021-01-14 02:00:00  9.890145e+05        -5476.201106
# 2021-01-14 03:00:00  9.803129e+05        -1281.616546
# 2021-01-14 04:00:00  9.785865e+05         1658.907515
# ...                           ...                 ...
# 2021-01-30 19:00:00  1.156711e+06         5357.105926
# 2021-01-30 20:00:00  1.131272e+06        -2633.614840
# 2021-01-30 21:00:00  1.105847e+06        -2053.592787
# 2021-01-30 22:00:00  1.081371e+06        -6117.728225
# 2021-01-30 23:00:00  1.052326e+06        -5905.563940
#
# [408 rows x 5 columns]

# %%
params = { 'metric': ['l2', 'auc'],
            'learning_rate': 0.005,
            "num_iterations": 200,
            "n_estimators": 200}

model = MultiOutputRegressor(lgb.LGBMRegressor(**params))
#model = MultiOutputRegressor(linear_model.LinearRegression())


overall_mape = np.zeros(n_days)
start_day = pd.to_datetime('2020-11-30 00:00:00')

for i in range(n_days):
    
    last_known_day = (start_day + pd.DateOffset(days=44+i))#.date()
    prediction_day = (last_known_day + pd.DateOffset(days=1))#.date()
    last_prediction_day = str((prediction_day + pd.DateOffset(days=1)))#.date())
    
    pred = create_direct_prediction(model, start_day=start_day, last_known_day=last_known_day, 
                             prediction_day=prediction_day)
    
    print(prediction_day)
    #prediction = pred.dropna()['Load (kW)'].values[17:41]
#    fact = data.loc[pred.dropna().index,'Load (kW)'].values[17:41]

#    overall_mape[i] = 100 * np.mean(np.abs(prediction - fact)) / np.mean(np.abs(fact))
    
    overall_pred.loc[str(prediction_day.date()), 'Direct Error Model'] = pred
    print(pred)
    
    #print(overall_pred.loc[str(prediction_day.date())])
    
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['Direct Error Model'].values, label='pred')
plt.legend()
plt.show()
#print('mape',overall_mape.mean())
# Out:
# 2021-01-14 00:00:00
# [-3315.87567807  1845.26041701    29.41869357 -5568.13207624
#  -4844.41756441 -4640.65343174 -3880.47847271 -2031.60480215
#  -2265.67119581 -4022.37165972 -3878.96268136 -3303.57828401
#  -3983.70071764 -3340.01593029 -3561.8880205   -230.97557798
#   6748.1848794   8955.00399268 16302.2230768  15779.77690749
#  16144.15553503 15571.54562083 11244.81460515 11152.52881882]
# 2021-01-15 00:00:00
# [-5105.74862859 -3616.74717028 -2430.09680049  -391.69596441
#   1299.82731175   671.38999493    30.95953685   156.48916358
#   1061.41409824   456.79534459  1698.02615343  3174.75328228
#   3230.69381814  3370.0760583   5845.35365967  5425.955676
#   8411.24556768 13487.38907214 14126.77552261 15005.29501532
#  14221.22918655 18482.38522907  9961.86132442  5846.03481272]
# 2021-01-16 00:00:00
# [ 2993.37013661  -226.23971109  2182.59307924 -1198.49027907
#    918.5460077   2069.93952731  1879.58399281   118.74290513
#   2590.72298636  2188.17993613  2834.02139     1826.28649939
#   4071.76496143  5772.82245199  5584.04835724  4033.40102042
#   4896.59732816  5346.76080844  9237.564052    7409.49703485
#   4579.22667953   510.86715008  -579.75993426  -304.19260438]
# 2021-01-17 00:00:00
# [-3348.13634256 -2583.19120067   339.24917615  4056.40377817
#   3785.39570636  2328.49169481   750.60884236 -1286.39029612
#  -1130.43419862 -1860.34557549  -644.98433185 -1933.38250879
#  -1211.49021136   271.62842151 -1112.12543381  3458.565901
#   5761.64107201  9050.25373062 10915.28775496 13092.48523595
#   5518.19540737 -2678.90269211 -4799.0840476  -1889.81044818]
# 2021-01-18 00:00:00
# [-2517.76312837  3735.16546293  4566.61443184 -2232.28496143
#  -2566.16763246 -2014.40384847 -5918.0498545  -7945.63393736
#  -5740.51577922 -5208.24668356 -3646.46176695 -2562.87251222
#  -2474.92854536  -962.98932763  1395.75659885  4084.8547311
#   2400.33539382  2724.59943314  -724.84148148   256.5286918
#   3007.50221048  7886.84639349  6964.61291791  2884.44262623]
# 2021-01-19 00:00:00
# [-11162.25317846  -6354.62066155  -4371.51108914  -5470.26038454
#   -3556.67054706   -624.75718065  -1735.6406316   -4098.42457708
#   -4585.07113763  -4414.84745522  -3899.50984805  -4272.30738571
#   -3424.50263252  -2888.25760568   -222.44800164   -330.02067357
#   -1578.67977715   3703.28995996  -5515.6613954  -11008.36360893
#  -15518.27193831  -8887.50947591 -19268.18347372  -6074.810406  ]
# 2021-01-20 00:00:00
# [-2948.88212164 -5771.27395726 -5020.34618732 -5844.99188775
#  -3206.64142593 -4610.65929855 -4854.98826204 -4510.02826689
#  -4094.19783986 -4072.64971649 -3963.49044871 -3755.19204661
#  -3682.1101593  -3097.80034385 -1857.35757904 -2719.25173136
#  -4898.50191326 -4373.2450351  -4364.14645083  5147.1262967
#  -3401.02994269 -9731.56930468 -9274.65342334 -7680.7945891 ]
# 2021-01-21 00:00:00
# [   970.88377311  -5856.30465995  -6350.5092141   -5392.45626714
#   -1500.67350741  -6081.05905819  -5811.18366041  -3196.55250973
#   -3679.93192908  -3811.76399702  -3450.40048284  -3635.62767545
#   -3483.62290568  -3340.48980986  -3009.57908183   -930.8031221
#    -477.65943224  -1186.51584235    351.74021967  -2810.0291748
#  -12566.61549048  -5098.97149621 -11491.65193465  -2673.24988009]
# 2021-01-22 00:00:00
# [ 2596.79915264 -7655.29890602 -5700.99114793 -2725.14804932
#  -4253.75484943 -2029.34777082 -1774.57244963 -1708.96085046
#   -952.29347004   -38.0947446    183.78742949   419.05148451
#   -754.98838296  -454.702576     680.34160947  2518.90406079
#   2549.8717661   4594.95903526 10144.08104299 11815.41386743
#   7576.52200606 13477.06306566 10252.88969443 10021.06314664]
# 2021-01-23 00:00:00
# [ 4749.9069885   -336.14329698  1964.16778527   876.87721327
#   1016.75838923  2479.92630001   156.45105192  1377.01320511
#   1663.10769628  1593.36459239  1806.73967557  1825.78264195
#   2585.833322    2267.95462597  2817.07141832   552.79978237
#  -1514.90089625  -959.82583935 -2144.58044308 -3039.04457031
#  -3572.6403244  -3321.24232499 -3871.99752051 -3805.87437418]
# 2021-01-24 00:00:00
# [-3315.85090823   505.74892196  4805.54804407  7525.00526859
#   5394.66583338  5728.09576573  1086.08160796  -298.43775771
#  -1494.71660279 -2205.60658306 -1925.01174934 -1683.3187417
#  -1274.89727907   -90.31830601  3244.58438074  7647.50029113
#   9058.11932278  8850.00444931 13905.31854978 13028.84148439
#  12760.53674874 10393.25975072  7246.21790907 13259.09820253]
# 2021-01-25 00:00:00
# [ 10827.78758331     33.52352415  -2396.44252917  -4232.07420248
#   -6425.08272409  -8388.42589193 -11963.48672588 -11044.11359278
#   -8274.16548958  -5927.11653095  -7064.52859706  -5279.37257792
#   -4122.27296303  -2169.53703475  -4877.48647281  -1637.77867545
#    8621.32230788   5143.86236728  -1016.53925338   3111.78156126
#     639.32515218    763.97698558   8970.75573066   7867.40075235]
# 2021-01-26 00:00:00
# [16642.14859347  7216.79191924  5493.34326366  4130.23290276
#   4109.94477092   218.06932135  2220.10333031 -1992.80483456
#  -2548.14074984 -2113.61866761 -2144.97370054 -3552.08054776
#  -2232.92191062  -778.93578839  1184.94227615  7317.67835089
#   8615.69666286 12775.74205896 15279.97607148 11507.91508152
#  12829.33707328  8270.46577865  9721.58280654 14241.06809166]
# 2021-01-27 00:00:00
# [  2875.54818902   1986.16954516   -907.13299006   -652.37198561
#    -902.53110065  -1927.95729441   4121.57094392  -2479.57856109
#   -2641.88593069  -2579.09011143  -2825.71334039  -2762.86665527
#   -3129.17954827  -2440.62527501   -753.68941379  -1447.95534047
#   -5670.73041921  -6727.45849686  -8947.97066697  -6623.01638434
#  -10190.45738393 -23206.25366688 -10905.93813598 -13814.96496461]
# 2021-01-28 00:00:00
# [ -3852.35269665  -3473.77930623  -6440.96600791  -1946.58606248
#   -3192.6051916   -4491.1671666   -4190.36826227  -3115.90083439
#   -3024.58534607  -2666.48277106  -2794.20496803  -2846.63341815
#   -3115.10118571  -2635.14079344   -176.62892706   1032.20382275
#   -3616.27659445 -13238.43762183  -5713.07008948  -1418.57018374
#   -2965.70184937  -9015.59289098 -12084.14190763  -8215.33887093]
# 2021-01-29 00:00:00
# [  912.87925851  2206.04309411  -725.75707958  -637.39627362
#   -630.32480369  -295.31794515 -1912.27016597  -833.22774765
#   -569.46516372 -1254.63916459  -875.74514856  -616.86852183
#    111.09132477   439.93309967   651.2213479     55.17720395
#   5165.42719918  9629.59784278  5606.6443564   7262.95639327
#   7162.3079926   4977.02146054  5092.76483332  2405.01084692]
# 2021-01-30 00:00:00
# [ 3551.35941628  3856.43408881  4343.77886775  4294.37220015
#   5012.82792723  3233.22284722  1481.01542944  1069.82046482
#   1210.69087506  1354.91239524  1484.3225649    817.15975267
#   1398.18326097  2226.27796339  2867.42931438  3627.43247485
#   -503.53625357 -3454.70238403 -3366.90946906  4138.76112072
#  -3484.97351372 -3789.20801679 -5577.10218926 -6345.93005093]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-232-aa2271c5b217> in <module>
#      18
#      19     pred = create_direct_prediction(model, start_day=start_day, last_known_day=last_known_day,
# ---> 20                              prediction_day=prediction_day)
#      21
#      22     print(prediction_day)
#
# <ipython-input-231-3a297bdb581d> in create_direct_prediction(model_name, start_day, last_known_day, prediction_day)
#      22     step = pd.date_range(start=prediction_day, periods=40, freq='H')
#      23
# ---> 24     X_pred = pd.DataFrame(res_X_train.loc[step,'Final_model'])
#      25     for i in range(16,40):
#      26         X_pred['model_'+str(i)] = X_pred['Final_model'].shift(-i).astype('float64')
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     887                     # AttributeError for IntervalTree get_value
#     888                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 889             return self._getitem_tuple(key)
#     890         else:
#     891             # we by definition only have the 0th axis
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1058     def _getitem_tuple(self, tup: Tuple):
#    1059         with suppress(IndexingError):
# -> 1060             return self._getitem_lowerdim(tup)
#    1061
#    1062         # no multi-index, so validate all of the indexers
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_lowerdim(self, tup)
#     829                     return section
#     830                 # This is an elided recursive call to iloc/loc
# --> 831                 return getattr(section, self.name)[new_key]
#     832
#     833         raise IndexingError("not applicable")
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     893
#     894             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 895             return self._getitem_axis(maybe_callable, axis=axis)
#     896
#     897     def _is_scalar_access(self, key: Tuple):
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1111                     raise ValueError("Cannot index with multidimensional key")
#    1112
# -> 1113                 return self._getitem_iterable(key, axis=axis)
#    1114
#    1115             # nested tuple slicing
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
#    1051
#    1052         # A collection of keys
# -> 1053         keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1054         return self.obj._reindex_with_indexers(
#    1055             {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1320             with option_context("display.max_seq_items", 10, "display.width", 80):
#    1321                 raise KeyError(
# -> 1322                     "Passing list-likes to .loc or [] with any missing labels "
#    1323                     "is no longer supported. "
#    1324                     f"The following labels were missing: {not_found}. "
#
# KeyError: "Passing list-likes to .loc or [] with any missing labels is no longer supported. The following labels were missing: DatetimeIndex(['2021-02-01 00:00:00', '2021-02-01 01:00:00',\n               '2021-02-01 02:00:00', '2021-02-01 03:00:00',\n               '2021-02-01 04:00:00',\n               ...\n               '2021-02-01 11:00:00', '2021-02-01 12:00:00',\n               '2021-02-01 13:00:00', '2021-02-01 14:00:00',\n               '2021-02-01 15:00:00'],\n              dtype='datetime64[ns]', length=16, freq='H'). See https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike"

# %%
plt.plot(overall_pred['Direct Error Model'].dropna()[:-16], label='error_pred')
plt.plot(res_y_train.loc[overall_pred['Direct Error Model'].dropna().index,'Error'], label='error_fact')
plt.legend()

# %%
np.corrcoef(overall_pred['Direct Error Model'].dropna().values[:-16].astype('float64'),
     res_y_train.loc[overall_pred['Direct Error Model'].dropna().index,'Error'].dropna().values.astype('float64'))
# Out:
# array([[1.        , 0.03304123],
#        [0.03304123, 1.        ]])

# %%
plt.plot(data.loc[overall_pred.dropna().index,'Load (kW)'].values, label='fact')
plt.plot(overall_pred.dropna()['CB Model'].values, label='CB Model')
plt.plot(overall_pred.dropna()['Prophet'].values, label='Prophet')
plt.plot(overall_pred.dropna()['LR Model'].values, label='LR Model')
plt.plot(overall_pred.dropna()['Theta Model'].values, label='Theta Model')
#plt.plot(overall_pred.dropna()['Direct RF Model'].values, label='Direct RF Model')
plt.legend()
plt.xlim(800,1300)
plt.show()
print('mape',overall_mape.mean())
# Out:
# mape 2.771529858587277

# %%
'''overall_pred.dropna().iloc[-192:,:].plot()
overall_pred.dropna().iloc[-192:,:].mean(axis=1).plot(lw=5)
plt.plot(fact,color='red')
plt.show()
# overall_pred = overall_pred.dropna()

plt.plot(prophet_prediction*.25 + cb_prediction*.25 + theta_prediction*.05 + linearNoWeather_prediction*.45,color='black')
plt.plot(prophet_prediction,color='black',alpha=0.3)
plt.plot(cb_prediction,color='black',alpha=0.3)
plt.plot(linearNoWeather_prediction,color='black',alpha=0.3)
plt.plot(theta_prediction,color='black',alpha=0.3)
plt.plot(fact,color='red')
plt.xlim(900,1170)
plt.show()'''
# Out:
# "overall_pred.dropna().iloc[-192:,:].plot()\noverall_pred.dropna().iloc[-192:,:].mean(axis=1).plot(lw=5)\nplt.plot(fact,color='red')\nplt.show()\n# overall_pred = overall_pred.dropna()\n\nplt.plot(prophet_prediction*.25 + cb_prediction*.25 + theta_prediction*.05 + linearNoWeather_prediction*.45,color='black')\nplt.plot(prophet_prediction,color='black',alpha=0.3)\nplt.plot(cb_prediction,color='black',alpha=0.3)\nplt.plot(linearNoWeather_prediction,color='black',alpha=0.3)\nplt.plot(theta_prediction,color='black',alpha=0.3)\nplt.plot(fact,color='red')\nplt.xlim(900,1170)\nplt.show()"

# %% [markdown]
# # Make single forecast from ensemble

# %%
prophet_prediction = overall_pred['Prophet'].dropna().iloc[-24:].values
linearNoWeather_prediction = overall_pred['LR Model'].dropna().iloc[-24:].values
cb_prediction = overall_pred['CB Model'].dropna().iloc[-24:].values
theta_prediction = overall_pred['Theta Model'].dropna().iloc[-24:].values

benchmark = data.loc['2021-01-30','Load (kW)'].values

final_prediction = prophet_prediction*.2 + cb_prediction*.15 + theta_prediction*.05 + linearNoWeather_prediction*.3+benchmark*.3

plt.plot(final_prediction,lw=3)
plt.plot(prophet_prediction,label='pr')
plt.plot(linearNoWeather_prediction,label='lin')
plt.plot(cb_prediction,label='cb')
plt.plot(theta_prediction,label='th')
plt.plot(benchmark, label='benchmark')
plt.legend()

np.savetxt('Submitted_Predictions/February-06-Kazmi-Hussain.csv', final_prediction)

# %%
jan19 = pd.read_csv('Submitted_Predictions/February-04-Kazmi-Hussain.csv', header=None)
jan19['fact'] = data.loc['2021-02-04','Load (kW)'].values
jan19 = jan19.dropna()
jan19.plot()

# %%
np.mean(np.abs(jan19[0] - jan19['fact']))# / np.mean(np.abs(jan19['fact']))
# Out:
# 11644.71975220883

# %%
np.mean(np.abs(data['Load (kW)'].loc['2021-01-18':'2021-01-23'].values - data['Load (kW)'].loc['2021-01-11':'2021-01-16'].values))
# Out:
# 31824.90631853498

# %%
fact = data.loc[overall_pred['Prophet'].dropna().index,'Load (kW)'].values[:-40]

# %%
overall_pred.to_csv('overall_pred.csv')

# %%
all_prophet_prediction = overall_pred['Prophet'].dropna()
all_linearNoWeather_prediction = overall_pred['LR Model'].dropna()
all_cb_prediction = overall_pred['CB Model'].dropna()
all_theta_prediction = overall_pred['Theta Model'].dropna()

# all_benchmark = data.loc['2021-01-27','Load (kW)'].values

all_final_prediction = all_prophet_prediction*.3 + all_cb_prediction*.25 + all_theta_prediction*.05 + all_linearNoWeather_prediction*.4

# %%
plt.plot(all_final_prediction.iloc[:-40], label='pred')
plt.plot(data.loc[all_final_prediction.index[:-40], 'Load (kW)'], label='fact')
plt.legend()

# %%
plt.scatter(all_final_prediction.iloc[:-40], data.loc[all_final_prediction.index[:-40], 'Load (kW)'])

np.corrcoef(all_final_prediction.iloc[:-40].values.astype('float'), data.loc[all_final_prediction.index[:-40], 'Load (kW)'].values.astype('float'))
# Out:
# array([[1.        , 0.95787223],
#        [0.95787223, 1.        ]])

# %%
error = all_final_prediction.iloc[:-40].values.astype('float') - data.loc[all_final_prediction.index[:-40], 'Load (kW)'].values.astype('float')

plt.plot(sm.tsa.stattools.pacf(error, nlags=200),'*--')

# %%
plt.plot(error)

# %% [markdown]
# # Define a mixture of experts model

# %%
y = data.loc[overall_pred.dropna().index,'Load (kW)'].dropna()
X = overall_pred.loc[y.index]

X['CB Model'] = X['CB Model'].astype('float')
X['LR Model'] = X['LR Model'].astype('float')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42, shuffle=False)

# X

# %%
mixture_model = lgb.LGBMRegressor()#n_estimators = 2000)
mixture_model = linear_model.LinearRegression()
mixture_model.fit(X_train,y_train)

y_pred = mixture_model.predict(X_test)

# plt.scatter(y_test, X_test['LR Model'])
# plt.scatter(y_test, y_pred)

# print(np.corrcoef(y_test, X_test['LR Model']))
# print(np.corrcoef(y_test, y_pred))

# print(np.mean(np.abs(y_test - X_test['LR Model'])))
# print(np.mean(np.abs(y_test - .05*X_test['Theta Model'] -.45*X_test['LR Model'] - .25*X_test['CB Model'] -.25*X_test['Prophet'])))
# print(np.mean(np.abs(y_test - y_pred)))

# mixture_model.coef_
