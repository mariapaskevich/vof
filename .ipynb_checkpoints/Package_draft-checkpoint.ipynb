# %%
#!pip install darts
#!pip install catboost

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
import statsmodels.tsa.stattools
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
import time
from darts import TimeSeries
from darts.models import (
    FFT,
    AutoARIMA,
    ExponentialSmoothing,
    Prophet,
    Theta,
    NBEATSModel
)
from darts.metrics import mape
from darts.utils.missing_values import fill_missing_values
import lightgbm as lgb
#from fbprophet import Prophet
from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.multioutput import MultiOutputRegressor
import lightgbm as lgb
from datetime import date

plt.rcParams['figure.figsize'] = [18, 8]
plt.rcParams.update({'font.size': 22})

# %%
data = pd.read_csv('sales_FOODS_3_090_TX_2.csv')
data.set_index('date', inplace=True)

# %%
data#['sales'].plot()
# Out:
#                           id       d store_id      item_id  sell_price  \
# date
# 2011-01-29  FOODS_3_090_TX_2     d_1     TX_2  FOODS_3_090        1.25
# 2011-01-30  FOODS_3_090_TX_2     d_2     TX_2  FOODS_3_090        1.25
# 2011-01-31  FOODS_3_090_TX_2     d_3     TX_2  FOODS_3_090        1.25
# 2011-02-01  FOODS_3_090_TX_2     d_4     TX_2  FOODS_3_090        1.25
# 2011-02-02  FOODS_3_090_TX_2     d_5     TX_2  FOODS_3_090        1.25
# ...                      ...     ...      ...          ...         ...
# 2016-06-15  FOODS_3_090_TX_2  d_1965     TX_2  FOODS_3_090        1.50
# 2016-06-16  FOODS_3_090_TX_2  d_1966     TX_2  FOODS_3_090        1.50
# 2016-06-17  FOODS_3_090_TX_2  d_1967     TX_2  FOODS_3_090        1.50
# 2016-06-18  FOODS_3_090_TX_2  d_1968     TX_2  FOODS_3_090        1.50
# 2016-06-19  FOODS_3_090_TX_2  d_1969     TX_2  FOODS_3_090        1.50
#
#               weekday  wday  month  year  event_name_1 event_type_1  \
# date
# 2011-01-29   Saturday     1      1  2011           NaN          NaN
# 2011-01-30     Sunday     2      1  2011           NaN          NaN
# 2011-01-31     Monday     3      1  2011           NaN          NaN
# 2011-02-01    Tuesday     4      2  2011           NaN          NaN
# 2011-02-02  Wednesday     5      2  2011           NaN          NaN
# ...               ...   ...    ...   ...           ...          ...
# 2016-06-15  Wednesday     5      6  2016           NaN          NaN
# 2016-06-16   Thursday     6      6  2016           NaN          NaN
# 2016-06-17     Friday     7      6  2016           NaN          NaN
# 2016-06-18   Saturday     1      6  2016           NaN          NaN
# 2016-06-19     Sunday     2      6  2016  NBAFinalsEnd     Sporting
#
#             event_name_2 event_type_2  snap_CA  snap_TX  snap_WI  sales
# date
# 2011-01-29           NaN          NaN        0        0        0  164.0
# 2011-01-30           NaN          NaN        0        0        0  215.0
# 2011-01-31           NaN          NaN        0        0        0   94.0
# 2011-02-01           NaN          NaN        1        1        0  127.0
# 2011-02-02           NaN          NaN        1        0        1   90.0
# ...                  ...          ...      ...      ...      ...    ...
# 2016-06-15           NaN          NaN        0        1        1    NaN
# 2016-06-16           NaN          NaN        0        0        0    NaN
# 2016-06-17           NaN          NaN        0        0        0    NaN
# 2016-06-18           NaN          NaN        0        0        0    NaN
# 2016-06-19  Father's day     Cultural        0        0        0    NaN
#
# [1969 rows x 17 columns]

# %% [markdown]
# # Calculate PACF features

# %%
def estimateSignificantLags(ts, nlags = 360, significantLags = 11): 
    pacf = sm.tsa.stattools.pacf(ts, nlags)
    lags = np.argsort(-np.abs(pacf))[1:significantLags+1]
    plt.plot(pacf,'*--')
    plt.plot(lags,pacf[lags],'o')
    return lags

# %%
lags = estimateSignificantLags(data['sales'], significantLags = 30)
# add lags for certain days
lags = np.unique(np.hstack([lags,[47,48,49,70,72,94,96,118,120,144]]))
print(np.sort(lags))
# Out:
# [ 47  48  49  70  72  94  96 118 120 144 227 228 229 230 231 232 233 234
#  235 236 237 238 239 240 241 242 243 244 245 246 247 248 260 261 262 263
#  264 265 266 267]

# %% [markdown]
# # Build a forecaster with lagged features

# %% [markdown]
# ## Recursive forecaster class
#
# - Works with models that use semantic ".fit(x,y), .predict(x,y)"
# - Takes dataset as input, column to predict needs to be specified in "target" paremeter
# - Adds lag features from an array of lags
# - Creates prediciton for a set time horizon with frequency days, hours, and so on (needs to match the dataset)
# - Each new prediction uses updated lags that contains previous predicted values for the set

# %%
class RecursiveForecaster():
    
    def __init__(self, data, target):
        self.x = data.drop(target, axis=1)
        self.y = data[target]

    def add_lag_features(self,lags):
        self.lags=lags
        for i in lags:
            self.x['lag_'+str(i)] = self.y.shift(i)    
            
    def create_prediction(self, model_name,
                          start_day='2011-02-29', 
                          last_known_day='2016-05-22', 
                          prediction_day='2016-05-23',
                          frequency='D',
                          horizon=10):    
    
        X_train = self.x.loc[start_day:last_known_day]
        y_train = self.y.loc[start_day:last_known_day]
        
        model_name.fit(X_train,y_train)

        pred_index = pd.date_range(start=prediction_day, 
                                   periods=horizon, 
                                   freq=frequency)
        
        pred_df = pd.DataFrame(index=pred_index, 
                               columns=[self.y.name])
        
        #Create prediction for each time step in pred_index
        for step in pred_index:
            indx = str(step)[:-9]
            #print(indx)
            X_pred = pd.DataFrame(self.x.loc[indx]).T
            x_index = self.x.loc[indx].name
            pred_df.loc[x_index] = model_name.predict(X_pred)
            
            #update features with lags containing lags of predicted value 
            for i in self.lags:
                self.x.loc[indx,'lag_'+str(i)] = pred_df.shift(i)

        return pred_df

# %% [markdown]
# ## Example of use

# %%
tmp = RecursiveForecaster(data[['sell_price','wday','month','sales']], 
                          target='sales')

tmp.add_lag_features([1,2,3,4,5,7,9,15,27])

#model = linear_model.LinearRegression()

"""model = CatBoostRegressor(verbose=False,
                          learning_rate = 0.01, 
                          depth=6,
                          l2_leaf_reg=4)"""

#model = RandomForestRegressor()
model = lgb.LGBMRegressor()

pred = tmp.create_prediction(model,
                      start_day='2011-03-29',
                      last_known_day='2016-04-10',
                      prediction_day='2016-04-11',
                      frequency='D',
                      horizon=24)

# %%
pred
# Out:
#                  sales
# 2016-04-11   44.897194
# 2016-04-12    40.16916
# 2016-04-13   46.340895
# 2016-04-14   46.486225
# 2016-04-15   72.087039
# 2016-04-16   98.980396
# 2016-04-17   84.953883
# 2016-04-18   51.284683
# 2016-04-19   40.125901
# 2016-04-20   48.149548
# 2016-04-21   40.942339
# 2016-04-22   72.291065
# 2016-04-23    94.18404
# 2016-04-24   69.237431
# 2016-04-25   45.898041
# 2016-04-26    47.03612
# 2016-04-27   49.306883
# 2016-04-28   50.664258
# 2016-04-29   64.017146
# 2016-04-30  101.954528
# 2016-05-01   78.501443
# 2016-05-02   50.359247
# 2016-05-03   51.915447
# 2016-05-04   52.617259

# %% [markdown]
# ## Plotting the results

# %%
pred.index = pred.index.astype('str')
plt.plot(pred)
plt.plot(tmp.y.loc[pred.index])

# %%
100 * np.mean(np.abs(pred.values - tmp.y.loc[pred.index].values)) / np.mean(np.abs(tmp.y.loc[pred.index].values))
# Out:
# 35.10039700714254
