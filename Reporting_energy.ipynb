# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [18, 8]
plt.rcParams.update({'font.size': 22})

# %%
results_df_B16_I8_p10 = pd.read_csv('../VOF/results/energy-results_df_B16_I8_p10.5.csv')
results_df_B16_I8_p11 = pd.read_csv('../VOF/results/energy-results_df_B16_I8_p11.5.csv')
results_df_B16_I8_p12 = pd.read_csv('../VOF/results/energy-results_df_B16_I8_p12.5.csv')
results_df_B16_I8_p10
# Out:
#     Unnamed: 0                       Model  Forecast error  Peak violations  \
# 0            0                Naive weekly        0.475294        26.069943
# 1            1                 Naive daily        0.635743        29.950498
# 2            2                       Theta        0.436556        36.014382
# 3            3                   RegLags24        0.586126        15.364574
# 4            4                  RegLags168        0.368779        22.970229
# 5            5                  RegLags336        0.330904        21.633441
# 6            6                    RegCov24        0.320095        22.320226
# 7            7                   RegCov168        0.251716        20.996772
# 8            8                   RegCov336        0.252383        20.881286
# 9            9                  RegCovLGBM        0.273489        20.587506
# 10          10                        Fact        0.000000        21.311887
# ...

# %%
results_df_B4_I2_p10 = pd.read_csv('../VOF/results/energy-results_df_B4_I2_p10.5.csv')
results_df_B4_I2_p11 = pd.read_csv('../VOF/results/energy-results_df_B4_I2_p11.5.csv')
results_df_B4_I2_p12 = pd.read_csv('../VOF/results/energy-results_df_B4_I2_p12.5.csv')
results_df_B4_I2_p12
# Out:
#     Unnamed: 0                       Model  Forecast error  Peak violations  \
# 0            0                Naive weekly        0.475294         0.913329
# 1            1                 Naive daily        0.635743         0.926519
# 2            2                       Theta        0.436556         1.327586
# 3            3                   RegLags24        0.586126         1.375708
# 4            4                  RegLags168        0.368779         0.937089
# 5            5                  RegLags336        0.330904         0.875000
# 6            6                    RegCov24        0.320095         0.795628
# 7            7                   RegCov168        0.251716         0.721069
# 8            8                   RegCov336        0.252383         0.778217
# 9            9                  RegCovLGBM        0.273489         0.750765
# 10          10                        Fact        0.000000         0.050202
# ...

# %%
results_df_B8_I4_p10 = pd.read_csv('../VOF/results/energy-results_df_B8_I4_p10.5.csv')
results_df_B8_I4_p11 = pd.read_csv('../VOF/results/energy-results_df_B8_I4_p11.5.csv')
results_df_B8_I4_p12 = pd.read_csv('../VOF/results/energy-results-df_B8_I4_p12.5.csv')
results_df_B8_I4_p12
# Out:
#     Unnamed: 0                       Model  Forecast error  Peak violations  \
# 0            0                Naive weekly        0.475294     1.936655e+00
# 1            1                 Naive daily        0.635743     2.022139e+00
# 2            2                       Theta        0.436556     9.577397e-01
# 3            3                   RegLags24        0.586126     2.846352e+00
# 4            4                  RegLags168        0.368779     1.935713e+00
# 5            5                  RegLags336        0.330904     1.793692e+00
# 6            6                    RegCov24        0.320095     1.401368e+00
# 7            7                   RegCov168        0.251716     1.342411e+00
# 8            8                   RegCov336        0.252383     1.463814e+00
# 9            9                  RegCovLGBM        0.273489     1.444804e+00
# 10          10                        Fact        0.000000     2.198033e-08
# ...

# %%
plt.scatter(results_df_B16_I8_p10['Forecast error'][0:10], results_df_B16_I8_p10['Peak violations'][0:10])
plt.scatter(results_df_B16_I8_p12['Forecast error'][0:10], results_df_B16_I8_p12['Peak violations'][0:10])
plt.scatter(results_df_B4_I2_p10['Forecast error'][0:10], results_df_B4_I2_p10['Peak violations'][0:10])
plt.scatter(results_df_B4_I2_p12['Forecast error'][0:10], results_df_B4_I2_p12['Peak violations'][0:10])
# plt.ylim(0,60)

print(np.corrcoef(results_df_B16_I8_p10['Forecast error'][0:10], results_df_B16_I8_p10['Peak violations'][0:10]))
print(np.corrcoef(results_df_B16_I8_p11['Forecast error'][0:10], results_df_B16_I8_p11['Peak violations'][0:10]))
print(np.corrcoef(results_df_B16_I8_p12['Forecast error'][0:10], results_df_B16_I8_p12['Peak violations'][0:10]))
print()

print(np.corrcoef(results_df_B8_I4_p10['Forecast error'][0:10], results_df_B8_I4_p10['Peak violations'][0:10]))
print(np.corrcoef(results_df_B8_I4_p11['Forecast error'][0:10], results_df_B8_I4_p11['Peak violations'][0:10]))
print(np.corrcoef(results_df_B8_I4_p12['Forecast error'][0:10], results_df_B8_I4_p12['Peak violations'][0:10]))
print()

print(np.corrcoef(results_df_B4_I2_p10['Forecast error'][0:10], results_df_B4_I2_p10['Peak violations'][0:10]))
print(np.corrcoef(results_df_B4_I2_p11['Forecast error'][0:10], results_df_B4_I2_p11['Peak violations'][0:10]))
print(np.corrcoef(results_df_B4_I2_p12['Forecast error'][0:10], results_df_B4_I2_p12['Peak violations'][0:10]))
print()
# Out:
# [[1.         0.28740989]
#  [0.28740989 1.        ]]
# [[1.         0.75476776]
#  [0.75476776 1.        ]]
# [[1.         0.78468317]
#  [0.78468317 1.        ]]
#
# [[1.         0.50634335]
#  [0.50634335 1.        ]]
# [[1.         0.81510007]
#  [0.81510007 1.        ]]
# [[1.         0.64294248]
#  [0.64294248 1.        ]]
#
# [[1.         0.46957446]
#  [0.46957446 1.        ]]
# [[1.         0.81510007]
#  [0.81510007 1.        ]]
# [[1.         0.65820504]
#  [0.65820504 1.        ]]

# %%
plt.scatter(results_df_B16_I8_p10['Peak violations'], results_df_B16_I8_p12['Peak violations'])
plt.plot(np.arange(0,50),np.arange(0,50))
plt.grid()
