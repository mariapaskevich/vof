# %%
import vof
from vof import forecaster
from vof import optimizer

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api as sm
from darts.utils.statistics import check_seasonality, plot_acf, plot_residuals_analysis
import statsmodels.tsa.stattools
from sklearn import linear_model
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor
import time
import random
#from fbprophet import Prophet
from sklearn.model_selection import train_test_split
from statsmodels.tsa.api import ExponentialSmoothing, SimpleExpSmoothing, Holt
from sklearn.multioutput import MultiOutputRegressor
import lightgbm as lgb
from datetime import date
import nevergrad as ng

plt.rcParams['figure.figsize'] = [18, 8]
plt.rcParams.update({'font.size': 22})

# %%
data = pd.read_csv("data/district/predictions_2019.csv", index_col=0, parse_dates=True)#pd.read_csv('sales_FOODS_3_090_TX_2.csv')
data.head(5)
# Out:
#                      Prophet 30d  CB Model 30d  Prophet 60d  LR Model 240d  \
# Time
# 2019-01-02 00:00:00     9.712369      9.516061     9.732844      10.082039
# 2019-01-02 01:00:00     9.537794      9.329764     9.526740       9.905469
# 2019-01-02 02:00:00     9.346844      9.225298     9.357172       9.752310
# 2019-01-02 03:00:00     9.238202      9.140338     9.258282       9.633302
# 2019-01-02 04:00:00     9.222486      9.122567     9.222533       9.600721
#
#                      LR Model 30d  LR Model 60d  LR Model 120d  Prophet 120d  \
# Time
# 2019-01-02 00:00:00     10.034193      9.860739       9.931228      9.475604
# 2019-01-02 01:00:00      9.848606      9.685257       9.755594      9.250441
# 2019-01-02 02:00:00      9.685450      9.537204       9.604944      9.048528
# 2019-01-02 03:00:00      9.547768      9.422706       9.488390      8.965614
# 2019-01-02 04:00:00      9.502948      9.403288       9.459666      8.902531
#
#                      Theta 30d  Theta 60d  Theta 120d  Theta 240d  \
# Time
# 2019-01-02 00:00:00   9.992034   9.986460   10.074619   10.037784
# 2019-01-02 01:00:00   9.799050   9.784246    9.843274    9.809841
# 2019-01-02 02:00:00   9.646126   9.618324    9.656499    9.620984
# 2019-01-02 03:00:00   9.534998   9.506044    9.530117    9.501419
# 2019-01-02 04:00:00   9.499663   9.469673    9.476750    9.455269
#
#                      CB Model 60d  CB Model 240d  CB Model 120d  Prophet 240d  \
# Time
# 2019-01-02 00:00:00      9.478454       9.477245       9.469355      9.521947
# 2019-01-02 01:00:00      9.314212       9.310756       9.320833      9.283847
# 2019-01-02 02:00:00      9.217455       9.230141       9.192942      9.021519
# 2019-01-02 03:00:00      9.155913       9.161070       9.141137      8.909141
# 2019-01-02 04:00:00      9.125739       9.136762       9.136573      8.850692
#
#                          Fact    SNaive
# Time
# 2019-01-02 00:00:00  9.791285  9.587180
# 2019-01-02 01:00:00  9.595427  9.421677
# 2019-01-02 02:00:00  9.538146  9.302606
# 2019-01-02 03:00:00  9.420105  9.151197
# 2019-01-02 04:00:00  9.364424  9.159970

# %% [markdown]
# # Creating forecast from Fact data
#
# We start with creating a forecaster oblect from data['Fact'] with target mentric (the one to predict) also equal to 'Fact'

# %%
tmp = forecaster.RecursiveForecaster(data[['Fact']], 
                          target='Fact')
tmp.y
# Out:
# Time
# 2019-01-02 00:00:00     9.791285
# 2019-01-02 01:00:00     9.595427
# 2019-01-02 02:00:00     9.538146
# 2019-01-02 03:00:00     9.420105
# 2019-01-02 04:00:00     9.364424
#                          ...
# 2019-12-31 19:00:00    12.082850
# 2019-12-31 20:00:00    11.582850
# 2019-12-31 21:00:00    11.257850
# 2019-12-31 22:00:00    10.887850
# 2019-12-31 23:00:00    10.482850
# Name: Fact, Length: 8736, dtype: float64

# %% [markdown]
# ## Estimating Lags and adding them to the object

# %%
def estimateSignificantLags(ts, nlags = 360, significantLags = 11): 
    pacf = sm.tsa.stattools.pacf(ts, nlags)
    lags = np.argsort(-np.abs(pacf))[1:significantLags+1]
    plt.plot(pacf,'*--')
    plt.plot(lags,pacf[lags],'o')
    return lags

# %%
lags = estimateSignificantLags(tmp.y, significantLags = 10)
# add lags for certain days
lags = np.unique(np.hstack([lags]))
print(np.sort(lags))
# Out:
# [  1   2   3   5  23  24  26  50 168 169]

# %%
tmp.add_lag_features(np.sort(lags))

# %%
tmp.x.head(5)
# Out:
#                         lag_1     lag_2     lag_3  lag_5  lag_23  lag_24  \
# Time
# 2019-01-02 00:00:00       NaN       NaN       NaN    NaN     NaN     NaN
# 2019-01-02 01:00:00  9.791285       NaN       NaN    NaN     NaN     NaN
# 2019-01-02 02:00:00  9.595427  9.791285       NaN    NaN     NaN     NaN
# 2019-01-02 03:00:00  9.538146  9.595427  9.791285    NaN     NaN     NaN
# 2019-01-02 04:00:00  9.420105  9.538146  9.595427    NaN     NaN     NaN
#
#                      lag_26  lag_50  lag_168  lag_169
# Time
# 2019-01-02 00:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 01:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 02:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 03:00:00     NaN     NaN      NaN      NaN
# 2019-01-02 04:00:00     NaN     NaN      NaN      NaN

# %% [markdown]
# ## Now the dataset is ready, so we can start building a dataframe with different predictions for further optimization.
# All predictions will be in the same dataframe optimization_df together with the Fact data.
# We run several prediction models

# %%
optimization_df = pd.DataFrame(tmp.y, columns=['Fact'])

models = {'LR': linear_model.LinearRegression(),
          'CB': CatBoostRegressor(verbose=False,learning_rate = 0.01,depth=6,l2_leaf_reg=4),
          'RF': RandomForestRegressor(),
          'LGBM': lgb.LGBMRegressor() }


for model in models.keys():
    optimization_df[model] = tmp.create_prediction(models[model],
                      start_day='2019-01-12',
                      last_known_day='2019-03-01',
                      prediction_day='2019-03-02',
                      frequency='H',
                      horizon=720)
# Out:
# LinearRegression()
# <catboost.core.CatBoostRegressor object at 0x7f90f66c6150>
# RandomForestRegressor()
# LGBMRegressor()

# %%
optimization_df = optimization_df.dropna()
optimization_df
# Out:
#                           Fact         LR         CB         RF       LGBM
# Time
# 2019-03-02 00:00:00  10.947910  10.933568  10.898989  10.907601  10.902972
# 2019-03-02 01:00:00  10.730205  10.737524  10.666039  10.642525  10.676169
# 2019-03-02 02:00:00  10.498403  10.547683  10.526944  10.546451  10.554631
# 2019-03-02 03:00:00  10.372299  10.371807  10.393229  10.359773  10.347762
# 2019-03-02 04:00:00  10.365991  10.369586  10.347148  10.346323  10.377326
# ...                        ...        ...        ...        ...        ...
# 2019-03-31 19:00:00  10.896059  10.884811  10.843793   10.90516  10.873305
# 2019-03-31 20:00:00  10.887494  10.856856  10.810256  10.865958  10.890975
# 2019-03-31 21:00:00  10.868426  10.807409  10.790033  10.796359  10.869045
# 2019-03-31 22:00:00  10.789726  10.757732  10.756812  10.728406  10.687622
# 2019-03-31 23:00:00  10.660102  10.644563  10.654663  10.573042  10.605079
#
# [720 rows x 5 columns]

# %%
plt.plot(optimization_df['Fact'])
plt.plot(optimization_df['LR'])
plt.plot(optimization_df['CB'])
plt.plot(optimization_df['RF'])
plt.plot(optimization_df['LGBM'])

# %% [markdown]
# # Optimizer to choose from several predictions
#
# Predictions are ready. Now we are creating a child class for Electricity Peak Case.
# We need the child class to pass there task-specific cost functions and other constant values like PEAK_POWER_LIMIT, BATTERY_CHARGE, BATTERY_CAPACITY end so on

# %%
class OptimalDecisionMakersElectricityPeak(optimizer.OptimalDecisionMakers):
    


    def __init__(self, data, target):
        super().__init__(data, target)
        self.EVALUATE = False
        self.TIME_HORIZON = 96
        self.DECISION_TIMESTEP = 24
        self.PEAK_POWER_LIMIT = 14
        self.BATTERY_CHARGE = 0
        self.BATTERY_CAPACITY = 150
        self.BATTERY_EFFICIENCY = .9
        
    def cost_function(self,solution):
        
        cumsum = np.cumsum(solution) + self.BATTERY_CHARGE

        #battery capacity penalty:
        violations_battery = (np.sum(np.where(cumsum>self.BATTERY_CAPACITY)) + np.sum(np.where(cumsum<0))) * 10000

        #penalty for putting electricity back to the grid
        if self.EVALUATE:
            grid_load = (self.y+solution).values
        else:
            grid_load = (self.candidate+solution).values
        violations_demand = -np.sum(grid_load[np.where(grid_load<0)]) * 10000

        #penlty for high peak in load
        margin = (self.PEAK_POWER_LIMIT - grid_load)
        violations_peak = - np.sum(margin[np.where(margin < 0)]) * 1000

        #penalty for battery losses
        battery_usage = (1 - self.BATTERY_EFFICIENCY) * np.sum(np.abs(solution)) * 1000

        total_cost = violations_battery + violations_demand + violations_peak + battery_usage
        #print(violations_battery,violations_demand,violations_peak,battery_usage)
        return total_cost
    
    
    def select_value_optimal_model(self,return_predictions=False):
        
        random.seed(42)
        
        self.optimal_decisions_df = pd.DataFrame(index=(self.x.index),columns=self.x.columns).iloc[:-self.TIME_HORIZON]
        
        for col in range(len(self.optimal_decisions_df.columns)):
            
            total_steps = range(0,len(self.x)-self.TIME_HORIZON,self.DECISION_TIMESTEP)
            recommendation = np.array([])

            for step in total_steps:
                
                par = ng.p.Array(shape=(self.TIME_HORIZON,)).set_bounds(lower=-80, upper=80)
                optimizer = ng.optimizers.CMA(parametrization=par, budget=5000)
                
                try:
                    self.candidate = self.x.iloc[step:step+self.TIME_HORIZON,col]
                except:
                    print(self.optimal_decisions_df.shape)
                    print(self.x.iloc[step:step+self.TIME_HORIZON,col])
                    
                step_recommendation = optimizer.minimize(self.cost_function)
                recommendation = np.append(recommendation,step_recommendation.value[0:self.DECISION_TIMESTEP])
                self.BATTERY_CHARGE = self.BATTERY_CHARGE + sum(step_recommendation.value[0:self.DECISION_TIMESTEP])
                
            self.optimal_decisions_df.iloc[:,col] = recommendation
            self.BATTERY_CHARGE = 0

        return self.optimal_decisions_df
    
    def evaluate(self):
        
        for col in range(len(self.optimal_decisions_df.columns)):
            
            cost_evaluation = (self.optimal_decisions_df.iloc[:,col]+self.x.Fact)[(self.optimal_decisions_df.iloc[:,col]+self.x.Fact)>self.PEAK_POWER_LIMIT].sum()
            print(col, cost_evaluation)
        return #cost_evaluation
        
    def select_value_optimal_hyperparameters():
        return

# %% [markdown]
# ## Now just creating an oblect of this child class using optimization_df from the previous steps

# %%
odm = OptimalDecisionMakersElectricityPeak(optimization_df,'Fact')

# %%
odm.x
# Out:
#                           Fact         LR         CB         RF       LGBM
# Time
# 2019-03-02 00:00:00  10.947910  10.933568  10.898989  10.907601  10.902972
# 2019-03-02 01:00:00  10.730205  10.737524  10.666039  10.642525  10.676169
# 2019-03-02 02:00:00  10.498403  10.547683  10.526944  10.546451  10.554631
# 2019-03-02 03:00:00  10.372299  10.371807  10.393229  10.359773  10.347762
# 2019-03-02 04:00:00  10.365991  10.369586  10.347148  10.346323  10.377326
# ...                        ...        ...        ...        ...        ...
# 2019-03-31 19:00:00  10.896059  10.884811  10.843793   10.90516  10.873305
# 2019-03-31 20:00:00  10.887494  10.856856  10.810256  10.865958  10.890975
# 2019-03-31 21:00:00  10.868426  10.807409  10.790033  10.796359  10.869045
# 2019-03-31 22:00:00  10.789726  10.757732  10.756812  10.728406  10.687622
# 2019-03-31 23:00:00  10.660102  10.644563  10.654663  10.573042  10.605079
#
# [720 rows x 5 columns]

# %% [markdown]
# ## Running optimizzation to select the optimal model

# %%
sol = odm.select_value_optimal_model()
sol
# Out:
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:08 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:16 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:23 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:30 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:37 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:44 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:51 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:22:59 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:06 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:13 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:20 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:27 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:34 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:41 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:48 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:23:55 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:02 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:09 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:16 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:23 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:30 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:37 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:44 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:51 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:24:58 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:05 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:12 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:20 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:27 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:35 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:43 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:51 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:25:58 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:06 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:14 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:21 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:29 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:37 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:44 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:52 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:26:59 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:07 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:14 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:22 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:30 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:37 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:45 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:27:53 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:00 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:08 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:15 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:23 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:30 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:38 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:46 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:28:53 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:01 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:08 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:16 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:24 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:31 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:39 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:46 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:29:54 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:01 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:09 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:17 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:24 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:32 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:40 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:47 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:30:55 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:02 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:10 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:18 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:25 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:33 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:40 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:48 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:31:56 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:03 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:11 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:19 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:26 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:34 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:41 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:49 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:32:57 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:04 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:12 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:20 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:27 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:35 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:43 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:50 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:33:58 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:06 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:13 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:21 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:28 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:36 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:44 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:51 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:34:59 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:07 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:14 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:22 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:30 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:37 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:45 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:35:53 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:01 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:08 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:16 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:24 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:31 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:39 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:47 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:36:55 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:03 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:10 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:18 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:25 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:33 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:41 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:49 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:37:56 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:38:04 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:38:12 2021)
# (8_w,17)-aCMA-ES (mu_w=5.1,w_1=31%) in dimension 96 (seed=nan, Mon Dec 20 22:38:20 2021)
#                          Fact        LR        CB        RF      LGBM
# Time
# 2019-03-02 00:00:00 -0.029089 -0.057614  1.184267  0.075156  0.096433
# 2019-03-02 01:00:00  0.168093  1.504096 -0.005615  0.007855 -0.005630
# 2019-03-02 02:00:00  0.046802 -0.002724 -0.006188  0.089890  0.069142
# 2019-03-02 03:00:00  0.027361 -0.129552  0.020887  0.043492  0.103295
# 2019-03-02 04:00:00 -0.001638 -0.005959 -0.007394  0.080007  0.003128
# ...                       ...       ...       ...       ...       ...
# 2019-03-27 19:00:00 -0.034800 -0.135031  0.018655  0.041035  0.004144
# 2019-03-27 20:00:00  0.022771  0.019403 -0.037270 -0.008471 -0.052160
# 2019-03-27 21:00:00  0.060454  0.017234 -0.021364  0.092678 -0.041483
# 2019-03-27 22:00:00  0.068072  0.188847 -0.036821  0.033679  0.051530
# 2019-03-27 23:00:00 -0.011213  0.359291 -0.099673 -0.003063 -0.009617
#
# [624 rows x 5 columns]

# %%
#plt.plot(sol.SNaive, label='solution')

plt.plot(odm.x.Fact, label='Fact')

plt.plot(sol['Fact']+odm.x.Fact, label='Fact+Fact')
plt.plot(sol['LR']+odm.x.Fact, label='LR+Fact')
plt.plot(sol['CB']+odm.x.Fact, label='CB+Fact')
plt.plot(sol['RF']+odm.x.Fact, label='RF+Fact')
plt.plot(sol['LGBM']+odm.x.Fact, label='LGBM+Fact')


plt.legend()

# %% [markdown]
# ## Evaluation returns outputs of cost function for each of the models:

# %%
EVALUATE = True
odm.evaluate()
# Out:
# 0 4182.564839460691
# 1 4274.597521981449
# 2 3846.8339899474236
# 3 3855.734347530717
# 4 3891.340176743668
